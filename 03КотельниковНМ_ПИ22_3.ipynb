# %% [markdown]
# # Форматы данных (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 4: Форматы данных"
# * https://docs.python.org/3/library/json.html
# * https://docs.python.org/3/library/pickle.html
# * https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/bs4ru.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Вывести все адреса электронной почты, содержащиеся в адресной книге `addres-book.json`

# %%
import json
with open('addres-book.json', 'r') as f:
  reader = json.load(f)
  for i in reader:
    print(i['email'])
# Out:
# faina@mail.ru
# robert@mail.ru

# %% [markdown]
# 2. Вывести телефоны, содержащиеся в адресной книге `addres-book.json`

# %%
for i in reader:
  print(*i['phones'])
# Out:
# {'phone': '232-19-55'} {'phone': '+7 (916) 232-19-55'}
# {'phone': '111-19-55'} {'phone': '+7 (916) 445-19-55'}

# %% [markdown]
# 3. По данным из файла `addres-book-q.xml` сформировать список словарей с телефонами каждого из людей.

# %%
from bs4 import BeautifulSoup
with open('addres-book-q.xml', 'r') as f1:
  reader_xml = BeautifulSoup(f1, 'xml')
  
list_of_names = []
list_of_phones = []
for ad in reader_xml.address_book.find_all('address'):
  list_of_names += [person.next for person in ad.find_all('name')]
  list_of_phones.append([phone.next for phone in ad.phones.find_all('phone')])

dict_name_phone = {i:j for i, j in zip(list_of_names,list_of_phones)}
for i in dict_name_phone:
  print(i,':', dict_name_phone[i])
# Out:
# Aicha Barki : ['+ (213) 6150 4015', '+ (213) 2173 5247']
# Francisco Domingos : ['+ (244-2) 325 023', '+ (244-2) 325 023']
# Maria Luisa : ['+ (244) 4232 2836']
# Abraao Chanda : ['+ (244-2) 325 023', '+ (244-2) 325 023']
# Beatriz Busaniche : ['+ (54-11) 4784 1159']
# Francesca Beddie : ['+ (61-2) 6274 9500', '+ (61-2) 6274 9513']
# Graham John Smith : ['+ (61-3) 9807 4702']

# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# ### JSON

# %%
import json

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`. Воспользовавшись модулем `json`, преобразуйте содержимое файла в соответствующие объекты python. Выведите на экран информацию о первых 3 пользователях.

# %%
from pprint import pprint 

with open('contributors_sample.json') as f:
    contributors = json.load(f)

pprint(contributors[:3])
# Out:
# [{'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'id': 35193,
#   'jobs': ['Energy engineer',
#            'Engineer, site',
#            'Environmental health practitioner',
#            'Biomedical scientist',
#            'Jewellery designer'],
#   'mail': 'jsalazar@gmail.com',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'username': 'uhebert'},
#  {'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'id': 91970,
#   'jobs': ['Music therapist',
#            'Volunteer coordinator',
#            'Designer, interior/spatial'],
#   'mail': 'bhudson@gmail.com',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'username': 'vickitaylor'},
#  {'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'id': 1848091,
#   'jobs': ['Management consultant',
#            'Engineer, structural',
#            'Lecturer, higher education',
#            'Theatre manager',
#            'Designer, textile'],
#   'mail': 'darren44@yahoo.com',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'username': 'sheilaadams'}]

# %% [markdown]
# 1.2 Выведите уникальные почтовые домены, содержащиеся в почтовых адресах людей

# %%
mails = [i['mail'] for i in contributors]
domen = set(i[i.index('@'):] for i in mails)
print(domen)
# Out:
# {'@gmail.com', '@hotmail.com', '@yahoo.com'}

# %% [markdown]
# 1.3 Напишите функцию, которая по `username` ищет человека и выводит информацию о нем. Если пользователь с заданным `username` отсутствует, возбудите исключение `ValueError`

# %%
def search(username):
  for i in contributors:
    if i['username'] == username:
      print(i)
search('sheilaadams')
# Out:
# {'username': 'sheilaadams', 'name': 'Julia Allen', 'sex': 'F', 'address': 'Unit 1632 Box 2971\nDPO AE 23297', 'mail': 'darren44@yahoo.com', 'jobs': ['Management consultant', 'Engineer, structural', 'Lecturer, higher education', 'Theatre manager', 'Designer, textile'], 'id': 1848091}

# %% [markdown]
# 1.4 Посчитайте, сколько мужчин и женщин присутсвует в этом наборе данных.

# %%
female, male = 0, 0 
for i in contributors:
  if i['sex'] == 'F':
    female += 1
  elif i['sex'] == 'M':
    male += 1
print(f'female = {female}\nmale = {male}')
# Out:
# female = 2136
# male = 2064

# %% [markdown]
# 1.5 Создайте `pd.DataFrame` `contributors`, имеющий столбцы `id`, `username` и `sex`.

# %%
import pandas as pd
contributors = pd.DataFrame.from_dict(contributors)[['id', 'username','sex']]
contributors
# Out:
#            id       username sex
# 0       35193        uhebert   F
# 1       91970    vickitaylor   F
# 2     1848091    sheilaadams   F
# 3       50969       nicole82   F
# 4      676820         jean67   M
# ...       ...            ...  ..
# 4195   423555  stevenspencer   F
# 4196    35251      rwilliams   M
# 4197   135887      lmartinez   F
# 4198   212714     brendahill   M
# 4199   344321       mistyray   F
#
# [4200 rows x 3 columns]

# %% [markdown]
# 1.6 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Объедините `recipes` с таблицей `contributors` с сохранением строк в том случае, если информация о человеке отсутствует в JSON-файле. Для скольких человек информация отсутствует?

# %%
recipes = pd.read_csv('recipes_sample.csv')
merge_recipes = recipes.merge(contributors, on = 'id',how = 'left')
merge_recipes[['username']].isnull().sum()
# Out:
# username    29830
# dtype: int64

# %% [markdown]
# ### pickle

# %%
import pickle

# %% [markdown]
# 2.1 На основе файла `contributors_sample.json` создайте словарь следующего вида:
# ```
# {
#     должность: [список username людей, занимавших эту должность]
# }
# ```

# %%
import json
with open('contributors_sample.json') as j:
  j = json.load(j)
dic = {}
for person in j:
  for job in person['jobs']:
    if job in dic.keys():
      dic[job] += [person['username']]
    else:
      dic[job] = [person['username']]
for i in dic:
  dic[i] = list(set(dic[i]))
dic
# Out:
# {'Energy engineer': ['melissa94',
#   'stacey47',
#   'robert71',
#   'amanda41',
#   'sextonsheila',
#   'cwheeler',
#   'annmoore',
#   'charles74',
#   'wardjames',
#   'ucarlson',
#   'rogersmichael',
#   'garysilva',
#   'clintonjones',
#   'wmcdaniel',
#   'martinezashley',
#   'smithjennifer',
#   'uhebert',
#   'timothynelson',
#   'pjames',
#   'johnsontheresa',
#   'smithjonathan'],
#  'Engineer, site': ['daniel04',
#   'wesley32',
#   'rossdoris',
#   'vjohnson',
#   'cynthia20',
#   'nancy12',
#   'morgan15',
#   'trantricia',
#   'zmejia',
#   'ericarobertson',
#   'natalieross',
#   'catherineross',
#   'tenglish',
#   'tpugh',
#   'reyesbrett',
#   'laurieholloway',
#   'dbooker',
#   'avaldez',
#   'andrea03',
#   'jessica92',
#   'austin18',
#   'samantha36',
#   'christophersmith',
#   'uhebert',
#   'brandidaniels',
#   'baileyvictoria',
#   'jasonvelez'],
#  'Environmental health practitioner': ['john93',
#   'hknox',
#   'james01',
#   'dward',
#   'dsmith',
#   'stephanie81',
#   'stephanie69',
#   'thomas33',
#   'chadandrews',
#   'nancytaylor',
#   'bakerjacob',
#   'ellisdennis',
#   'bradleyalexander',
#   'andrewwoods',
#   'fmaldonado',
#   'kathleenbarnett',
#   'melaniejohnson',
#   'qolson',
#   'jonathanchristian',
#   'whitejoseph',
#   'james74',
#   'uhebert',
#   'jessegreen',
#   'tanderson',
#   'xjohnson',
#   'ztaylor',
#   'gonzalesdaniel',
#   'tranronald',
#   'susan54'],
#  'Biomedical scientist': ['brandi41',
#   'sarahirwin',
#   'betty20',
#   'epittman',
#   'jeremy66',
#   'xmiller',
#   'bnorris',
#   'katkins',
#   'smithheather',
#   'leebenjamin',
#   'katherinewalters',
#   'robertsmith',
#   'friedmanronald',
#   'barbara93',
#   'ginacantrell',
#   'limadeline',
#   'richard23',
#   'ambermartinez',
#   'uhebert',
#   'stephanie16',
#   'derekschmidt',
#   'scotttyrone',
#   'bakertammie'],
#  'Jewellery designer': ['joseph26',
#   'heatherphillips',
#   'donnacurry',
#   'daltonmelissa',
#   'zachary61',
#   'megan77',
#   'victoriachavez',
#   'ojames',
#   'stewartpamela',
#   'garciaduane',
#   'mark85',
#   'lopezantonio',
#   'bfernandez',
#   'williamsbill',
#   'elainerodriguez',
#   'dali',
#   'brandigreen',
#   'leonnicole',
#   'richardherman',
#   'uhebert',
#   'sdaniel',
#   'harrisonjeffery',
#   'sarahleonard'],
#  'Music therapist': ['amanda48',
#   'gmoore',
#   'framirez',
#   'rebekahmcguire',
#   'medinagregory',
#   'xbutler',
#   'hailey83',
#   'stephanie29',
#   'johnadams',
#   'cunninghamamy',
#   'brittanymeyer',
#   'bfernandez',
#   'steven69',
#   'dali',
#   'david94',
#   'john81',
#   'whitneynixon',
#   'stevensmichael',
#   'xrogers',
#   'timothythompson',
#   'michael28',
#   'vickitaylor',
#   'wtaylor',
#   'susan16',
#   'lrivers',
#   'elizabeth80',
#   'joshuanewman',
#   'bakertammie'],
#  'Volunteer coordinator': ['opatel',
#   'josephbell',
#   'kevinmckenzie',
#   'gabriel63',
#   'fuentescharles',
#   'rjohnson',
#   'derricksaunders',
#   'geraldmcdonald',
#   'vickitaylor',
#   'areyes',
#   'susanglenn',
#   'pricejames',
#   'garciajenna',
#   'leroy35',
#   'oscarbaldwin',
#   'brian15',
#   'daypatrick',
#   'fstanley'],
#  'Designer, interior/spatial': ['holmescarolyn',
#   'joseph54',
#   'hollandryan',
#   'gregory58',
#   'flemingmeghan',
#   'cwheeler',
#   'christopherrobinson',
#   'roymichael',
#   'trussell',
#   'claireschultz',
#   'donna67',
#   'lynningram',
#   'vorozco',
#   'clarkpam',
#   'vazquezjames',
#   'pduarte',
#   'diane15',
#   'mendozarobert',
#   'steven33',
#   'bmartin',
#   'vickitaylor',
#   'tracythomas',
#   'william68',
#   'davidmejia'],
#  'Management consultant': ['nbush',
#   'nancylawrence',
#   'swood',
#   'sheilaadams',
#   'sbeasley',
#   'aaronobrien',
#   'williamsdaniel',
#   'annemitchell',
#   'robert16',
#   'moraleshayley',
#   'egray',
#   'davidyoung',
#   'kingdustin',
#   'mark32',
#   'rubenmiller',
#   'charles66',
#   'johnsonemily',
#   'sarahfoley',
#   'jeffreyduarte',
#   'laurathomas',
#   'millskristen',
#   'robert56',
#   'mbean',
#   'kathrynlewis',
#   'robertrichardson',
#   'beniteztravis',
#   'daviddunn',
#   'joshuasandoval',
#   'imccarthy',
#   'jprince',
#   'benjamin98',
#   'yvargas',
#   'martineztracey'],
#  'Engineer, structural': ['brandi41',
#   'lmathews',
#   'karenhuang',
#   'sarah21',
#   'jeremiah97',
#   'sheilaadams',
#   'dana83',
#   'jpena',
#   'nancy23',
#   'npope',
#   'jgreen',
#   'staceynguyen',
#   'robin46',
#   'hughesmaria',
#   'ana38',
#   'oadams',
#   'jenniferwagner',
#   'andrea19',
#   'kgutierrez',
#   'qhernandez',
#   'dparker',
#   'jeffreycrane',
#   'charles71',
#   'jeanne11',
#   'coopermelissa',
#   'sarastone'],
#  'Lecturer, higher education': ['carterpatricia',
#   'jennifer74',
#   'georgeallen',
#   'andrew22',
#   'clayalexander',
#   'john47',
#   'pamelamason',
#   'sheilaadams',
#   'jeanne01',
#   'woodmarissa',
#   'jellis',
#   'sandovalamber',
#   'kjenkins',
#   'christinapena',
#   'avaldez',
#   'wjohnson',
#   'martinezsandra',
#   'james09',
#   'lisamorales',
#   'pjohnson',
#   'campbellemily',
#   'jhines',
#   'traci94',
#   'kirk17',
#   'hansenstephen',
#   'william68',
#   'amber03'],
#  'Theatre manager': ['amysmith',
#   'thomas57',
#   'nmorris',
#   'awilliams',
#   'sheilaadams',
#   'bmartinez',
#   'lshepherd',
#   'fitzgeraldcaleb',
#   'joseph76',
#   'hansendavid',
#   'jasonboone',
#   'icervantes',
#   'linda24',
#   'ortegalisa',
#   'kimberly91',
#   'douglas36',
#   'dali',
#   'clarkchristine',
#   'samuel80',
#   'chase81',
#   'cmalone',
#   'tyler57',
#   'matthew12',
#   'rodriguezjamie'],
#  'Designer, textile': ['paula65',
#   'jpoole',
#   'nicolethornton',
#   'racheljones',
#   'gmiller',
#   'adriana33',
#   'tpratt',
#   'sheilaadams',
#   'christina88',
#   'christina29',
#   'ujenkins',
#   'cynthiawebb',
#   'adkinsangela',
#   'jarvismichael',
#   'travisgalloway',
#   'owenjonathan',
#   'melinda57',
#   'mariofrank',
#   'colleenthompson',
#   'kaylanichols'],
#  'Mechanical engineer': ['oconnorwilliam',
#   'emilymason',
#   'rachel78',
#   'melissa86',
#   'nperez',
#   'pmclaughlin',
#   'shari69',
#   'djimenez',
#   'lunarichard',
#   'ashley14',
#   'cwilson',
#   'shirleybrewer',
#   'lawrencetaylor',
#   'garrisonamanda',
#   'jaimelambert',
#   'kramirez',
#   'chasebarnes',
#   'sextonelizabeth',
#   'stevensonmatthew',
#   'uporter',
#   'sierraterrell',
#   'cdavis',
#   'lisa69',
#   'farleyregina',
#   'nicole82',
#   'mark20',
#   'brendahill',
#   'bskinner',
#   'stephanie87',
#   'angela48',
#   'ncarroll',
#   'ariel99'],
#  'Retail banker': ['fblackwell',
#   'john84',
#   'kathleen15',
#   'brent34',
#   'alisontodd',
#   'rileybridget',
#   'qkim',
#   'smack',
#   'bflores',
#   'thicks',
#   'burtonmichelle',
#   'joshua38',
#   'toconnor',
#   'ryan72',
#   'jcopeland',
#   'xmaldonado',
#   'alvinwilson',
#   'mooresarah',
#   'smithgeoffrey',
#   'ejennings',
#   'johnmoore',
#   'kimberly91',
#   'jonathan18',
#   'jenniferwagner',
#   'stevenspencer',
#   'chelsealewis',
#   'eileen79',
#   'peter01',
#   'nicole82',
#   'parsonsbetty',
#   'schultzsteven',
#   'lgutierrez',
#   'jared17',
#   'perezmichael'],
#  'Barrister': ['ricky88',
#   'mooregary',
#   'dnavarro',
#   'wleach',
#   'thompsonsierra',
#   'asheppard',
#   'gshah',
#   'robert16',
#   'npope',
#   'dsanchez',
#   'ashley23',
#   'jacobsims',
#   'hallheather',
#   'stephen24',
#   'hurleywilliam',
#   'james11',
#   'westwilliam',
#   'lynnsmith',
#   'connoryang',
#   'matthew00',
#   'destinyjones',
#   'nicole82',
#   'dana71',
#   'shane08',
#   'joseph98',
#   'adamsmith',
#   'annamcdonald',
#   'leeanne',
#   'smolina',
#   'krichard',
#   'ogriffin',
#   'higginsdavid',
#   'esanchez',
#   'yolanda03',
#   'iedwards'],
#  'Network engineer': ['rodney40',
#   'christopherdaniel',
#   'emartin',
#   'robertskatrina',
#   'ycohen',
#   'fwilliams',
#   'kbarber',
#   'brian45',
#   'jeremyjones',
#   'jean67',
#   'jgreen',
#   'michaelwarner',
#   'martinwesley',
#   'james11',
#   'mcmahondavid',
#   'gsmith',
#   'shawnlewis',
#   'cmolina',
#   'figueroarhonda',
#   'debraholmes',
#   'lgutierrez',
#   'jay16',
#   'snyderandrew',
#   'hmata',
#   'mward',
#   'tvillegas',
#   'spencerlisa'],
#  'Youth worker': ['william12',
#   'elizabeth23',
#   'carterpatricia',
#   'williamsdawn',
#   'jgonzalez',
#   'josephanderson',
#   'anthonyjohnson',
#   'nelsonchristy',
#   'johnsonmelissa',
#   'christina64',
#   'jean67',
#   'tranjohn',
#   'xtran',
#   'travisrich',
#   'jamesshawn',
#   'chasemartin',
#   'alexandrawu',
#   'mark85',
#   'iharris',
#   'gary46',
#   'markchavez',
#   'tara46',
#   'charles65',
#   'benjamingonzales',
#   'schultzsteven',
#   'eturner',
#   'ricky09',
#   'vwilson',
#   'ronald90',
#   'natalie71',
#   'kimberlymccarty',
#   'michael00',
#   'martinvasquez'],
#  'Primary school teacher': ['jessicajames',
#   'brent51',
#   'taylorbrown',
#   'john16',
#   'jean67',
#   'adamslisa',
#   'brian89',
#   'stephen47',
#   'courtneyanderson',
#   'michelle00',
#   'brittanymeyer',
#   'morrisadrian',
#   'zwall',
#   'gregoryadam',
#   'williamsbill',
#   'martin92',
#   'jeffery87',
#   'fwalker',
#   'stewartjason',
#   'fergusondouglas',
#   'jason94',
#   'christopher60'],
#  'Engineer, broadcasting (operations)': ['znichols',
#   'stokescheryl',
#   'stevensmicheal',
#   'collinpadilla',
#   'joseph17',
#   'tsmith',
#   'natalieross',
#   'amanda12',
#   'mary54',
#   'jean67',
#   'amy15',
#   'allisonbrian',
#   'rebecca50',
#   'garciaemily',
#   'smithlauren',
#   'chasemartin',
#   'ejennings',
#   'gnichols',
#   'matthew61',
#   'brad80',
#   'philliphernandez',
#   'millsbrandy',
#   'cking',
#   'caseyvelasquez',
#   'meganbrewer',
#   'vhoward'],
#  'Designer, ceramics/pottery': ['patriciasimon',
#   'wallvictoria',
#   'flemingmeghan',
#   'jacobsonmarcus',
#   'pamelamason',
#   'alittle',
#   'jacob71',
#   'jellis',
#   'briananderson',
#   'lopezangela',
#   'blackcolleen',
#   'maybrandi',
#   'jillian23',
#   'isanders',
#   'alexander68',
#   'aaron76',
#   'martineznoah',
#   'sallen',
#   'ronald41',
#   'james67',
#   'adamsmith',
#   'katherine85',
#   'thomassara',
#   'rrangel',
#   'jason94',
#   'jeanne11',
#   'fpatterson',
#   'robert18',
#   'jodiklein',
#   'lewisalexandra'],
#  'Engineer, energy': ['christopherdaniel',
#   'avaughan',
#   'davidreynolds',
#   'avilachelsea',
#   'xbutler',
#   'shannon14',
#   'rachelproctor',
#   'thompsonkristina',
#   'ryanbarajas',
#   'vasquezkevin',
#   'ashley59',
#   'elizabethwaters',
#   'igreen',
#   'andrew58',
#   'devinmoore',
#   'brittany65',
#   'james67',
#   'adamlee',
#   'dustinwhite',
#   'fowlerbrian',
#   'christopher06',
#   'lewisalexandra'],
#  'Engineer, manufacturing': ['gary53',
#   'gilbertsteven',
#   'emilymason',
#   'ddelacruz',
#   'lucas04',
#   'rebeccadavis',
#   'jerryjackson',
#   'emily43',
#   'michaelvasquez',
#   'romeromark',
#   'fbrown',
#   'murphygabriella',
#   'spearsjerry',
#   'clambert',
#   'linda67',
#   'lpeck',
#   'james67',
#   'fisherlaurie',
#   'mdavis',
#   'osmith',
#   'ryanphillips',
#   'ronald90',
#   'scottreyes',
#   'jennifer42',
#   'ojones',
#   'jbecker',
#   'hensleybrittney'],
#  'Designer, furniture': ['leslie58',
#   'heidi22',
#   'jessicanewton',
#   'stephaniehouse',
#   'mcleanvanessa',
#   'tracysmith',
#   'barbara87',
#   'johncunningham',
#   'benjaminparker',
#   'woodmarissa',
#   'alex54',
#   'joan88',
#   'randy45',
#   'hodgesvirginia',
#   'ubarnes',
#   'xbrown',
#   'michaelphillips',
#   'gerald12',
#   'ylowe',
#   'justinmarsh',
#   'wolfmary',
#   'chungchristine',
#   'jennifercraig',
#   'ycruz'],
#  'Sport and exercise psychologist': ['millertracy',
#   'walterreynolds',
#   'william12',
#   'kyle02',
#   'morrismichelle',
#   'gregory67',
#   'michellecollins',
#   'manuelalexander',
#   'robinsonnicole',
#   'xtran',
#   'adam18',
#   'cassidy28',
#   'briana29',
#   'xhaas',
#   'hollyedwards',
#   'amandathompson',
#   'evansjason',
#   'wuerika',
#   'jesse14',
#   'christophersanchez',
#   'jennifer43',
#   'sampsontammy',
#   'jean88'],
#  'Hospital pharmacist': ['gary53',
#   'robertmorrow',
#   'ashleyparker',
#   'nicolelong',
#   'johnsontanner',
#   'hpace',
#   'ygreen',
#   'desiree54',
#   'danielsmith',
#   'justindeleon',
#   'glennroberson',
#   'jamessmith',
#   'andresmorse',
#   'alexrussell',
#   'jessicanash',
#   'frankoliver',
#   'ralphgraham',
#   'jasoncollier',
#   'lopezjessica',
#   'sampsontammy',
#   'ellisalbert',
#   'higginsdavid'],
#  'Surveyor, minerals': ['elizabeth23',
#   'leahdonovan',
#   'jessicajames',
#   'lmartinez',
#   'jlynch',
#   'christinecooper',
#   'melissa19',
#   'john16',
#   'garyscott',
#   'johnsonmatthew',
#   'vwatts',
#   'jeffreyduarte',
#   'sarahzamora',
#   'kevinsims',
#   'zmiller',
#   'patrick89',
#   'jdavis',
#   'destiny06',
#   'angieromero',
#   'thomasmiller',
#   'jodi82',
#   'shanejennings',
#   'fowlerbrian',
#   'wsmith',
#   'scooper',
#   'sampsontammy',
#   'garzachristopher',
#   'tonysmith',
#   'chavezanthony',
#   'laura29'],
#  'Geochemist': ['pcollins',
#   'john55',
#   'richardsalyssa',
#   'michaelhartman',
#   'trevoralvarez',
#   'jessicacruz',
#   'valenciamonica',
#   'garybrown',
#   'gpark',
#   'dylan44',
#   'christopher22',
#   'laurie16',
#   'jacqueline96',
#   'robertnewman',
#   'ygreen',
#   'pittsveronica',
#   'chadjohnson',
#   'roger61',
#   'christine21',
#   'pjohnson',
#   'dpowers',
#   'adamlee',
#   'brian64',
#   'xferrell',
#   'robertmiller',
#   'tammy85',
#   'wolfmary',
#   'ryan37',
#   'sampsontammy',
#   'ecarson'],
#  'Restaurant manager': ['ricardowhite',
#   'hardylucas',
#   'adamsthomas',
#   'gglover',
#   'nicholasbradley',
#   'ycook',
#   'johnsonstephen',
#   'billy33',
#   'qmacias',
#   'dgriffith',
#   'barrettnicole',
#   'rivasjamie',
#   'scott31',
#   'jessica56',
#   'carolharris',
#   'tanyajohnson',
#   'michael79',
#   'youngjoseph',
#   'gsharp',
#   'shepherdlori',
#   'amoore',
#   'hansenjason',
#   'deanna25',
#   'robbinskara',
#   'jameslee',
#   'owenjonathan',
#   'mcintyrejoseph',
#   'smithdaniel',
#   'hmata',
#   'sampsontammy'],
#  'Clinical psychologist': ['robertsontodd',
#   'gregorycox',
#   'ngonzalez',
#   'vegaantonio',
#   'daviscarl',
#   'michael63',
#   'sandersvanessa',
#   'mitchellkyle',
#   'rosejack',
#   'fcooper',
#   'jonathan18',
#   'cbass',
#   'brad46',
#   'martinezwilliam',
#   'shirleygarrison',
#   'douglas33',
#   'daniellerodgers',
#   'timothy32',
#   'racheldrake',
#   'ysmith',
#   'kimberlymccarty',
#   'sschmidt',
#   'pcallahan',
#   'awebster',
#   'benjamin54'],
#  'Sports development officer': ['cparker',
#   'william12',
#   'reidangie',
#   'louisgonzalez',
#   'taylorhenson',
#   'kristophermcdaniel',
#   'hailey83',
#   'keith43',
#   'swilliams',
#   'craigallen',
#   'kellyatkinson',
#   'george20',
#   'dhill',
#   'jessica56',
#   'watsonsarah',
#   'stanleyteresa',
#   'qpatrick',
#   'marissa26',
#   'teresaballard',
#   'lpittman',
#   'jonathan18',
#   'bryandonald',
#   'keith23',
#   'jennifer33',
#   'leeanne',
#   'tonysmith',
#   'luis44'],
#  'Firefighter': ['collinskayla',
#   'snyderdenise',
#   'emiller',
#   'gary94',
#   'arthurterry',
#   'lewisjohn',
#   'florestina',
#   'loweryjennifer',
#   'melissa86',
#   'petergonzalez',
#   'ramirezvictoria',
#   'lorianderson',
#   'oward',
#   'unolan',
#   'william80',
#   'johnsontanner',
#   'kellyatkinson',
#   'chapmandiana',
#   'lopezangela',
#   'christopherdyer',
#   'browndenise',
#   'jennifertrevino',
#   'lynningram',
#   'davidturner',
#   'jacobsims',
#   'jeremiaharmstrong',
#   'karen23',
#   'jonathan18',
#   'brittneysmith',
#   'ashleygibson',
#   'kristiarmstrong',
#   'christina12',
#   'lrivers',
#   'scott14',
#   'edwardsmegan',
#   'ipratt'],
#  'Charity fundraiser': ['douglas91',
#   'jgonzalez',
#   'harrisoncatherine',
#   'vthomas',
#   'garciatravis',
#   'burtonmichelle',
#   'vwatts',
#   'brittney74',
#   'zacharymyers',
#   'jackie01',
#   'wpowell',
#   'powersemily',
#   'rebecca03',
#   'fsalazar',
#   'jonathan18',
#   'morriswilliam',
#   'davidtaylor',
#   'carrmonique',
#   'katherine85',
#   'thomaschristopher',
#   'jason09',
#   'ztaylor',
#   'nbrown',
#   'rmills',
#   'jodimiller',
#   'scotttyrone'],
#  'Insurance underwriter': ['amanda48',
#   'jessica44',
#   'gregory58',
#   'kvalentine',
#   'aaron94',
#   'kimberlygrant',
#   'stephaniemoore',
#   'wilsonlori',
#   'joseph64',
#   'luismoody',
#   'dorothy34',
#   'cassidy28',
#   'lreynolds',
#   'desiree54',
#   'nmiller',
#   'rking',
#   'kimberly15',
#   'michael53',
#   'hartmonique',
#   'tammyshannon',
#   'kristina75',
#   'gonzalezkim',
#   'williamsonkyle',
#   'tracy45',
#   'williamle'],
#  'Analytical chemist': ['kellyjorge',
#   'medinadean',
#   'emilywilliams',
#   'lbrooks',
#   'isaac00',
#   'matthewwells',
#   'amorris',
#   'schan',
#   'barrettnicole',
#   'russellfrancisco',
#   'claireschultz',
#   'brentsawyer',
#   'sarahwright',
#   'adkinsangela',
#   'hallerik',
#   'robert56',
#   'michael53',
#   'mbarnes',
#   'christina73',
#   'pwoods',
#   'erika98',
#   'taylor88',
#   'justinhull',
#   'rburke',
#   'saradavis',
#   'normanjacqueline',
#   'haysjacob'],
#  'Holiday representative': ['michaelellis',
#   'kathryn38',
#   'brianbailey',
#   'carlos61',
#   'tracey50',
#   'andersontony',
#   'gloria11',
#   'kburnett',
#   'floydmelissa',
#   'amandamartinez',
#   'michaelvasquez',
#   'knightjoan',
#   'wpowell',
#   'patriciapaul',
#   'dmcdonald',
#   'gibsonjohnny',
#   'jessicaward',
#   'wrobinson',
#   'millskristen',
#   'bakerkristy',
#   'pamela63',
#   'ronaldatkinson',
#   'ashleymarshall',
#   'kyle15',
#   'michael53',
#   'carpentererin',
#   'davidwalker',
#   'daniel43',
#   'nscott',
#   'annenguyen',
#   'richardsstephen',
#   'rogerssharon',
#   'kcampos'],
#  'Scientist, research (physical sciences)': ['gilbertsteven',
#   'blanchardjackie',
#   'loweryjennifer',
#   'edwardszachary',
#   'nicholasbradley',
#   'walkermichaela',
#   'djimenez',
#   'jerryjackson',
#   'xrodriguez',
#   'ryandouglas',
#   'moorezachary',
#   'masonchavez',
#   'carolharris',
#   'damonmercer',
#   'leslie69',
#   'youngangela',
#   'nicholas72',
#   'mcmahondavid',
#   'laura09',
#   'mendozadana',
#   'simmonstanya',
#   'dylan67',
#   'rryan'],
#  'Financial planner': ['edgar62',
#   'ruizsteven',
#   'christopher67',
#   'smithronald',
#   'bnorris',
#   'smithkara',
#   'clayalexander',
#   'medinakenneth',
#   'jacobsbrittany',
#   'mariaporter',
#   'keith43',
#   'edward93',
#   'jeffreydavila',
#   'mcbridelaura',
#   'amber13',
#   'bmendoza',
#   'bushdana',
#   'gford',
#   'stricklanddevon',
#   'mcmahondavid',
#   'codyhampton',
#   'coxandrew',
#   'andrea31',
#   'jeffery66',
#   'ericowen',
#   'orobles'],
#  'Psychiatric nurse': ['lhill',
#   'deborahalvarez',
#   'dickersonkevin',
#   'medinakenneth',
#   'kevinpeters',
#   'anthony69',
#   'williamsmith',
#   'coleolivia',
#   'makaylaking',
#   'vlee',
#   'michael37',
#   'williamjohnson',
#   'thomas96',
#   'hhowe',
#   'wellsfrancisco',
#   'danielpotts',
#   'lisa04',
#   'amandatyler',
#   'qsmith',
#   'tanderson',
#   'mariasmith',
#   'hawkinswilliam',
#   'chase94',
#   'douglashendricks',
#   'uguerra',
#   'davidfisher',
#   'nataliejohnson'],
#  'Audiological scientist': ['leslie63',
#   'danielle01',
#   'rosejennifer',
#   'miguelwolf',
#   'davidsontyrone',
#   'jillibarra',
#   'cruzchristian',
#   'daypatrick',
#   'patriciafranco',
#   'bethbonilla',
#   'brownjohn',
#   'johnsonmatthew',
#   'kevinvaldez',
#   'dennissanchez',
#   'ian25',
#   'morrisadrian',
#   'markcooley',
#   'andreathornton',
#   'westwilliam',
#   'thomas96',
#   'nancymullins',
#   'kristiarmstrong',
#   'donnagonzalez',
#   'gina44',
#   'nelsoneugene',
#   'brandonparks'],
#  'Programmer, applications': ['leslie58',
#   'philiptanner',
#   'agonzalez',
#   'spencersteven',
#   'omahoney',
#   'scottanna',
#   'lfriedman',
#   'jeffreyburke',
#   'lisaberry',
#   'lucasyoung',
#   'joejackson',
#   'dhill',
#   'ujenkins',
#   'ikhan',
#   'brandon58',
#   'graytanya',
#   'barrettrebecca',
#   'panderson',
#   'stricklanddevon',
#   'oadams',
#   'gonzalezshawn',
#   'thomas96',
#   'daniellechen',
#   'gaustin',
#   'nichole23',
#   'rebeccaryan'],
#  'Phytotherapist': ['christopherdaniel',
#   'william12',
#   'trevinodawn',
#   'jessica44',
#   'adamsrobert',
#   'sharpheather',
#   'alexander04',
#   'colin60',
#   'msmith',
#   'khanbrandon',
#   'rogersmichael',
#   'emily43',
#   'ydavis',
#   'fergusonjerry',
#   'brooketurner',
#   'michael41',
#   'michellehernandez',
#   'kimberly91',
#   'thomas96',
#   'longgabriel',
#   'travisgalloway',
#   'nicolethomas',
#   'rlong',
#   'zacosta',
#   'susanmoran',
#   'ehicks',
#   'michael00',
#   'bakerjessica'],
#  'Records manager': ['zmcpherson',
#   'kim69',
#   'rebekahmcguire',
#   'ucohen',
#   'qramos',
#   'stephaniemoore',
#   'alex54',
#   'jgreen',
#   'bbrewer',
#   'qcastro',
#   'paulterrell',
#   'phillip45',
#   'thomas96',
#   'xyoung',
#   'hallcarolyn',
#   'denniskim',
#   'brian64',
#   'johnsonashley',
#   'debbiemarshall',
#   'hensleymary',
#   'whitney83',
#   'brentgutierrez',
#   'nashwilliam',
#   'smithmichael'],
#  'Secondary school teacher': ['jessica78',
#   'alyssa94',
#   'elizabeth19',
#   'btownsend',
#   'nataliemoore',
#   'mhurley',
#   'russelljeffrey',
#   'amy84',
#   'crobinson',
#   'courtney00',
#   'alexisstuart',
#   'amandasmith',
#   'kathrynweber',
#   'jocelyn88',
#   'adamsdavid',
#   'lpruitt',
#   'vramirez',
#   'laurabriggs',
#   'bobby15',
#   'andersonallison',
#   'michael23',
#   'mistyharris',
#   'wgordon',
#   'sstevens',
#   'oliverstephen',
#   'martindonald',
#   'leesandra',
#   'angelasmith',
#   'amygray',
#   'snguyen'],
#  'Futures trader': ['cardenasjorge',
#   'racheljones',
#   'sjones',
#   'qbuckley',
#   'davidsontyrone',
#   'ocollier',
#   'sarah16',
#   'jmarshall',
#   'jessicacruz',
#   'alicemoreno',
#   'emilyfreeman',
#   'joejackson',
#   'thomas36',
#   'bellsandra',
#   'gford',
#   'turnerkimberly',
#   'donaldhess',
#   'alexrussell',
#   'tmitchell',
#   'lisa04',
#   'martindonald',
#   'david27',
#   'margaret94',
#   'jasonvelez',
#   'matthew20',
#   'davidfisher',
#   'brownstephanie',
#   'vlee'],
#  'Programmer, multimedia': ['jasonrowe',
#   'david42',
#   'ncordova',
#   'calderonjoshua',
#   'philiptanner',
#   'briannalee',
#   'miranda64',
#   'george48',
#   'amy15',
#   'bflores',
#   'gbates',
#   'kristin79',
#   'romankelly',
#   'cruznathan',
#   'tara46',
#   'martin92',
#   'turnerkimberly',
#   'hjones',
#   'ocampos',
#   'james09',
#   'gonzalezshawn',
#   'richardsara',
#   'raymond30',
#   'fterrell',
#   'mary99',
#   'ashleymarshall',
#   'martindonald',
#   'vazquezmitchell',
#   'amanda55',
#   'kelleyerica',
#   'kimberlylopez',
#   'rwilliams',
#   'oroberson',
#   'copelandolivia',
#   'lancedean',
#   'meganbrewer'],
#  'Public affairs consultant': ['donnacurry',
#   'cruzwilliam',
#   'nataliejohnson',
#   'nelsonchristy',
#   'stephaniemcguire',
#   'walkermichaela',
#   'michaelalexander',
#   'robertsbradley',
#   'herringrobert',
#   'wellsregina',
#   'jonathanjohnson',
#   'kreynolds',
#   'markdeleon',
#   'amber50',
#   'weberlisa',
#   'martindonald',
#   'scott92',
#   'buchanancarrie',
#   'curtisallen',
#   'rachel93',
#   'shawnking',
#   'stonechris'],
#  'Therapeutic radiographer': ['rblack',
#   'ryanmurray',
#   'kvalentine',
#   'medinabarbara',
#   'ljohnson',
#   'benjaminparker',
#   'michaelanderson',
#   'nbennett',
#   'rleblanc',
#   'susanmcclain',
#   'andreawilliams',
#   'glovercarlos',
#   'benjamin66',
#   'mwillis',
#   'lesliesingleton',
#   'edavies',
#   'david67',
#   'santiagocindy',
#   'oliverstephen',
#   'kylegoodman',
#   'mschmidt',
#   'lopezjessica',
#   'jonesmiguel'],
#  'IT trainer': ['williamsdawn',
#   'heidiritter',
#   'brenda64',
#   'xmitchell',
#   'ljohnson',
#   'rstanley',
#   'adamslisa',
#   'pkane',
#   'brittney74',
#   'josephcarroll',
#   'powellashley',
#   'zjoseph',
#   'paula33',
#   'briannasmith',
#   'kim52',
#   'rking',
#   'olee',
#   'echavez',
#   'yjones',
#   'melaniejohnson',
#   'collinscynthia',
#   'jtucker',
#   'johntaylor',
#   'katherine85',
#   'stephanie16',
#   'jroth',
#   'tshelton',
#   'vanessa04',
#   'xalexander'],
#  'Location manager': ['ubell',
#   'dmartinez',
#   'ingramjordan',
#   'davidsonjody',
#   'taylorbrown',
#   'kennethfoster',
#   'jacobsbrittany',
#   'reiddawn',
#   'ljohnson',
#   'jamesholder',
#   'hernandezlaura',
#   'travisprice',
#   'whernandez',
#   'jessicalang',
#   'crichard',
#   'tiffany46',
#   'delgadoandrew',
#   'kennethjones',
#   'orozcopeggy',
#   'paige45',
#   'ihaley',
#   'ecarson',
#   'booneluis',
#   'kbrandt',
#   'qwade',
#   'jennifer44',
#   'lewisamanda',
#   'jking',
#   'whiteamy',
#   'ysmith',
#   'donaldking',
#   'robyn94',
#   'helenhall',
#   'robert18'],
#  'Production engineer': ['alyssa94',
#   'lbrooks',
#   'cody91',
#   'victoriachavez',
#   'annemitchell',
#   'gabriel63',
#   'jimmy32',
#   'hwang',
#   'chapmandiana',
#   'patrick94',
#   'iwatkins',
#   'williamsgabriela',
#   'mariafowler',
#   'nwest',
#   'julia04',
#   'lsmith',
#   'irussell',
#   'karen23',
#   'stephanieanderson',
#   'burnsbenjamin',
#   'pacerachael',
#   'tonyrusso',
#   'rodriguezsusan',
#   'racheldrake',
#   'xherman',
#   'wendycross',
#   'nashwilliam',
#   'npadilla'],
#  'Chief Operating Officer': ['riosmichael',
#   'kellyjorge',
#   'edavis',
#   'wluna',
#   'fwilliams',
#   'howelldwayne',
#   'jeremiah97',
#   'kblack',
#   'williamrussell',
#   'gregory94',
#   'jimmy32',
#   'rleblanc',
#   'barbara76',
#   'qfowler',
#   'nancy94',
#   'laurieholloway',
#   'charles49',
#   'amber87',
#   'brandonjenkins',
#   'englishlisa',
#   'brittanymeyer',
#   'hughesmaria',
#   'marissa26',
#   'ronaldvaldez',
#   'stonechris',
#   'xthomas',
#   'laceysmith',
#   'stewartjason',
#   'brianna63',
#   'cameron82',
#   'devintran',
#   'juarezernest',
#   'figueroarhonda',
#   'bethany97',
#   'perrymatthew',
#   'beanangela',
#   'susan16',
#   'patrick86',
#   'wendycross',
#   'gilesdeborah',
#   'linda91'],
#  'Hospital doctor': ['jamesdunn',
#   'fuentescharles',
#   'derrick72',
#   'crawfordedward',
#   'pmunoz',
#   'johnsondawn',
#   'matthewhooper',
#   'npatton',
#   'ubrown',
#   'bradleyalexander',
#   'wellsregina',
#   'fosterruth',
#   'youngjoseph',
#   'nwest',
#   'charles18',
#   'sweber',
#   'fstanley',
#   'vincent02',
#   'timothygilmore',
#   'wendycross',
#   'millerdavid',
#   'joshuacampbell',
#   'hlane',
#   'amanda85'],
#  'Radiation protection practitioner': ['sstrickland',
#   'ogoodwin',
#   'fowleradam',
#   'briannalee',
#   'rodrigueztiffany',
#   'erica32',
#   'alowe',
#   'dgriffith',
#   'sbarnett',
#   'grimesjanet',
#   'mdouglas',
#   'connoryang',
#   'kellylisa',
#   'mmitchell',
#   'loganmeyer',
#   'tiffany57',
#   'ocollins',
#   'jessica76',
#   'xferrell',
#   'tyler30',
#   'wendycross',
#   'millerdavid',
#   'shawkins',
#   'rachel87',
#   'enelson',
#   'gabriel30',
#   'jonesmichael'],
#  'Printmaker': ['sanchezsheila',
#   'colin37',
#   'carlosschaefer',
#   'hessangela',
#   'tparks',
#   'fryeolivia',
#   'mark71',
#   'patrick34',
#   'asheppard',
#   'christina64',
#   'erica76',
#   'dnelson',
#   'jennifer96',
#   'igreen',
#   'mosleyamanda',
#   'richardsara',
#   'steven33',
#   'nelsonrachel',
#   'iortiz',
#   'stacythomas',
#   'dpeterson',
#   'rossshelly',
#   'wsmith',
#   'jared17',
#   'fjohnson',
#   'conradsamuel'],
#  'Publishing copy': ['yvonne67',
#   'anthony75',
#   'ashleyhale',
#   'deanna09',
#   'swood',
#   'gshah',
#   'dsanchez',
#   'tpugh',
#   'serranostacey',
#   'daniel50',
#   'yvalenzuela',
#   'peter02',
#   'rzavala',
#   'jacobsdaniel',
#   'igreen',
#   'uorozco',
#   'garyshea',
#   'vargasjoshua',
#   'dana68',
#   'moorejonathon',
#   'davidsondouglas',
#   'harrisonjeffery',
#   'hmata',
#   'wsmith',
#   'dalton03',
#   'thomasfinley',
#   'wwinters',
#   'alexandra55',
#   'egreen',
#   'christinagreen',
#   'smithmichael'],
#  'Research scientist (life sciences)': ['brandy31',
#   'fblackwell',
#   'jeffreylane',
#   'hawkinsandrea',
#   'jesus56',
#   'jimtorres',
#   'brian45',
#   'gharrison',
#   'haleyjessica',
#   'jorge62',
#   'xpaul',
#   'rleblanc',
#   'christopher22',
#   'ugutierrez',
#   'smithkatherine',
#   'travis57',
#   'jonathanchristian',
#   'jeanneparker',
#   'fhughes',
#   'alexanderberger',
#   'cristina76',
#   'riosjohn',
#   'gabriel80',
#   'xstephens',
#   'carolineedwards',
#   'rfrye',
#   'wsmith',
#   'ohamilton',
#   'raymondperry',
#   'ian64',
#   'stevenbrooks',
#   'angela48',
#   'karen22'],
#  'Chief Technology Officer': ['brownbrandon',
#   'kaitlyn65',
#   'edwardsharp',
#   'bradylarsen',
#   'ytownsend',
#   'ethanmcdaniel',
#   'richard73',
#   'nmorris',
#   'vegaantonio',
#   'amanda12',
#   'gregory94',
#   'nicholas85',
#   'ryandouglas',
#   'samantha65',
#   'vrodriguez',
#   'stanleyteresa',
#   'waltergina',
#   'ashlee22',
#   'ogonzalez',
#   'ismith',
#   'moorejonathon',
#   'jason09',
#   'xreese',
#   'hawkinswilliam',
#   'tina76',
#   'jessicafoley',
#   'marissa82',
#   'ebeasley',
#   'richjoseph'],
#  'Call centre manager': ['richardsonshannon',
#   'villarrealcynthia',
#   'thomaschristina',
#   'christiehuang',
#   'dianajohnson',
#   'deanna09',
#   'jasminpeterson',
#   'gshah',
#   'johnsonmatthew',
#   'robertortiz',
#   'sanchezdonna',
#   'qcastro',
#   'courtneymendez',
#   'paige45',
#   'stewartjohn',
#   'ashlee22',
#   'zpowers',
#   'philliphernandez',
#   'michellemcfarland',
#   'gaustin',
#   'paulmartinez',
#   'michael66'],
#  'Chief Executive Officer': ['john51',
#   'jasonhill',
#   'johnsonalicia',
#   'raymondwells',
#   'bishopchristopher',
#   'lewisrobert',
#   'amybrady',
#   'eforbes',
#   'michaelalexander',
#   'christopherhodges',
#   'emilyfreeman',
#   'coleolivia',
#   'amberjohns',
#   'russellchristopher',
#   'amy79',
#   'amber40',
#   'wdaniel',
#   'ashlee22',
#   'georgedavis',
#   'hrich',
#   'jennifer82',
#   'ltran',
#   'meagan74',
#   'coopermelissa',
#   'fpatterson',
#   'kimsalinas'],
#  'Purchasing manager': ['bennettzachary',
#   'ninamartinez',
#   'juliepatrick',
#   'ronald66',
#   'brianaharrison',
#   'allisonbrian',
#   'ijones',
#   'robertestes',
#   'jenny81',
#   'gregorygriffith',
#   'hollyedwards',
#   'ayu',
#   'priceryan',
#   'ashlee22',
#   'donald21',
#   'lee46',
#   'kparker',
#   'kirk17',
#   'fnguyen',
#   'cheryl75',
#   'jonesshane',
#   'wtaylor',
#   'bradleyburton',
#   'bcross',
#   'ronaldroy',
#   'lewisalexandra'],
#  'Engineer, petroleum': ['gomezjohn',
#   'michaelsheppard',
#   'progers',
#   'millerpaul',
#   'ubuckley',
#   'kathy92',
#   'leebenjamin',
#   'cwilson',
#   'cunninghamamy',
#   'kaitlynshelton',
#   'allenhannah',
#   'elliskenneth',
#   'xescobar',
#   'wmelendez',
#   'alopez',
#   'leeharold',
#   'darren44',
#   'john81',
#   'lopezlisa',
#   'aclayton',
#   'douglas33',
#   'swoodward',
#   'michael02',
#   'danielbarton',
#   'vbridges',
#   'mpierce',
#   'davidfisher'],
#  'Social researcher': ['erojas',
#   'pgarza',
#   'nathan55',
#   'nhernandez',
#   'emilymoss',
#   'hmartinez',
#   'brett59',
#   'zmartin',
#   'douglasbrown',
#   'claytonmark',
#   'kevinshelton',
#   'ronaldvaldez',
#   'spearsjerry',
#   'iadams',
#   'swoodward',
#   'elizabethhamilton',
#   'fnguyen',
#   'kristinallen',
#   'sheenabaker',
#   'zterrell',
#   'christina12',
#   'nstrickland',
#   'michellewalker'],
#  'Publishing rights manager': ['jessicajames',
#   'bryceevans',
#   'gstevens',
#   'heatherriley',
#   'fwilliams',
#   'mark27',
#   'yhernandez',
#   'nperez',
#   'kimberlyallen',
#   'hilljasmine',
#   'ashley14',
#   'courtney28',
#   'laura16',
#   'isaacwilliams',
#   'mariesmith',
#   'normataylor',
#   'linda03',
#   'wrobinson',
#   'douglas36',
#   'aprilgarcia',
#   'davidfisher',
#   'swoodward',
#   'james96',
#   'erika98',
#   'brooksstephen',
#   'susanclay',
#   'westethan',
#   'judithlewis',
#   'thomasfinley',
#   'jasonvelez',
#   'andersoneugene',
#   'amanda85',
#   'lonniebarnett',
#   'triciaknapp',
#   'anthonyphillips'],
#  'Tax adviser': ['djimenez',
#   'ecoleman',
#   'samantha65',
#   'washingtonanne',
#   'danielramos',
#   'cassidy28',
#   'michelle00',
#   'gcarey',
#   'donaldhess',
#   'xwilliams',
#   'stefanie88',
#   'wangvincent',
#   'denisewilliams',
#   'cheryl12',
#   'donald28',
#   'ralphgraham',
#   'gthomas',
#   'ureed',
#   'traci94',
#   'andrewsalinas',
#   'julia21',
#   'angela45',
#   'tateadam',
#   'wmcgee',
#   'johnsonjulie'],
#  'Customer service manager': ['jenny76',
#   'nelsonpatricia',
#   'epittman',
#   'bennettwanda',
#   'kaisermelissa',
#   'lisa09',
#   'monicawilliams',
#   'qmacias',
#   'qbarnes',
#   'brandon01',
#   'timothydeleon',
#   'sanchezlisa',
#   'xrichardson',
#   'amoore',
#   'rachelkelley',
#   'stevensmichael',
#   'leejessica',
#   'donald28',
#   'parksdebra',
#   'cheryl29',
#   'christina19',
#   'monique00',
#   'richardwhite',
#   'ruizdiane',
#   'nterry',
#   'orodgers',
#   'natalie71',
#   'lancedean',
#   'mward'],
#  'Forensic psychologist': ['barnesmichael',
#   'wallvictoria',
#   'belltonya',
#   'andersontony',
#   'jeremy27',
#   'unolan',
#   'katherinehenderson',
#   'amanda97',
#   'xhaas',
#   'andersoncraig',
#   'smithjennifer',
#   'cristian07',
#   'brian42',
#   'john86',
#   'lpeck',
#   'mmitchell',
#   'donald28',
#   'schultzsteven',
#   'joshua05',
#   'vmarsh',
#   'johnsonpeter',
#   'tracy45',
#   'vhoward',
#   'smithdanielle',
#   'foxkelly',
#   'richjoseph'],
#  'Financial adviser': ['lhernandez',
#   'jameswilliam',
#   'selenamcconnell',
#   'nicholasbradley',
#   'mary62',
#   'jeffreysmith',
#   'wmcdaniel',
#   'andrew18',
#   'brittanywarner',
#   'mark32',
#   'briana28',
#   'berryjohn',
#   'mruiz',
#   'estephenson',
#   'ericagraves',
#   'georgesanchez',
#   'mariah30',
#   'andersonkristen',
#   'donald28',
#   'cassandra57',
#   'kparker',
#   'veronicaschmitt',
#   'wsmith',
#   'kimberly10'],
#  'Photographer': ['dward',
#   'hessangela',
#   'asmith',
#   'xmiller',
#   'shane66',
#   'hwillis',
#   'mccoylogan',
#   'nescobar',
#   'smcknight',
#   'danielle53',
#   'kjenkins',
#   'charles66',
#   'ipena',
#   'charles65',
#   'isanders',
#   'michael23',
#   'ochapman',
#   'stephanie41',
#   'robertsaudrey',
#   'donald28',
#   'julia21',
#   'tateadam',
#   'ashley12',
#   'mcdanielrobert',
#   'susanwilson',
#   'xjones',
#   'jeffreyguzman'],
#  'Health and safety adviser': ['morrismichelle',
#   'munozadam',
#   'harrisoncatherine',
#   'stacey47',
#   'hpatel',
#   'christinecooper',
#   'shieldssabrina',
#   'amybrady',
#   'susanguerrero',
#   'ssmith',
#   'rogersmichael',
#   'samantha42',
#   'juliedavis',
#   'shirleybrewer',
#   'delgadojason',
#   'lukebonilla',
#   'moodydavid',
#   'navarrojeffrey',
#   'iferrell',
#   'brad80',
#   'ianbooth',
#   'dana68',
#   'carlos09',
#   'nthompson',
#   'brian64',
#   'tammyshannon',
#   'justinhull',
#   'marquezjeffrey',
#   'fitzpatrickalan',
#   'benjamin98',
#   'grahammary',
#   'ycruz',
#   'colleenthompson',
#   'kaylanichols'],
#  'Product/process development scientist': ['connieporter',
#   'kayla95',
#   'troy12',
#   'dsmith',
#   'progers',
#   'trevoralvarez',
#   'christinecooper',
#   'benjamin16',
#   'lgraves',
#   'qmartin',
#   'tharvey',
#   'kmcdonald',
#   'herringrobert',
#   'randy45',
#   'ericacarpenter',
#   'fhall',
#   'kirk26',
#   'moodydavid',
#   'gzimmerman',
#   'clarkpam',
#   'charles06',
#   'patrick98',
#   'rjackson',
#   'jennifer82',
#   'davidsondouglas',
#   'carrie44',
#   'beanangela',
#   'david31',
#   'judithlewis',
#   'jamiepotts',
#   'jennifercraig',
#   'thomasmann'],
#  'Ceramics designer': ['whitejessica',
#   'robyn98',
#   'ryanmurray',
#   'garciadarren',
#   'craigallen',
#   'matthewhooper',
#   'adam04',
#   'iholland',
#   'moodydavid',
#   'richard95',
#   'iphillips',
#   'jenna83',
#   'evanprice',
#   'sandra00',
#   'josephcourtney',
#   'nmartinez',
#   'zhenry',
#   'henrybutler',
#   'josephcole',
#   'morenomicheal',
#   'ipeters',
#   'mcdonaldkyle',
#   'lewisamanda',
#   'perezlance',
#   'caseymorris'],
#  'Secretary/administrator': ['christopherdaniel',
#   'ubrandt',
#   'asmith',
#   'joneskimberly',
#   'rarcher',
#   'padillabrenda',
#   'nbennett',
#   'justin94',
#   'ijones',
#   'ashley14',
#   'gbates',
#   'wrightgregory',
#   'grace88',
#   'zgonzalez',
#   'moodydavid',
#   'wmelendez',
#   'linda24',
#   'mccoyjonathan',
#   'egolden',
#   'taylor73',
#   'kellycross',
#   'olee',
#   'martin92',
#   'kevin60',
#   'jeffreymcclain',
#   'erika95',
#   'cameron82',
#   'walkerpaul',
#   'whitneyanderson',
#   'tarahunt',
#   'feliciadominguez',
#   'ochoavictoria',
#   'smithdaniel',
#   'james42'],
#  'Patent attorney': ['ricardowhite',
#   'karenrhodes',
#   'wking',
#   'casemackenzie',
#   'ypowell',
#   'bolsen',
#   'ianlandry',
#   'ivan25',
#   'czamora',
#   'christineperez',
#   'rachelproctor',
#   'reesejohn',
#   'scottriley',
#   'sharonkrueger',
#   'kellersteven',
#   'brittanybender',
#   'bwagner',
#   'patriciamcgee',
#   'youngjames',
#   'uharris',
#   'moodydavid',
#   'davidbriggs',
#   'longgabriel',
#   'cferguson',
#   'fernandezjonathan',
#   'hunterchristopher',
#   'ncervantes',
#   'ryanphillips',
#   'ashleyorozco',
#   'scott14',
#   'jean88'],
#  'Hotel manager': ['michelle21',
#   'dwilliams',
#   'hicksjeff',
#   'michaelmorrow',
#   'edwardszachary',
#   'gshah',
#   'ryandouglas',
#   'shane12',
#   'brookeburke',
#   'jcopeland',
#   'brentsawyer',
#   'elliskenneth',
#   'christinecampbell',
#   'brian15',
#   'linda67',
#   'cferguson',
#   'danielle13',
#   'nthompson',
#   'melanielee',
#   'zhardin',
#   'igonzalez',
#   'bwilliams'],
#  'Quantity surveyor': ['garciajon',
#   'lhill',
#   'wallsfrederick',
#   'briannasmith',
#   'panderson',
#   'smithgeoffrey',
#   'pamela79',
#   'josephmartin',
#   'codyestes',
#   'katie56',
#   'jodigonzalez',
#   'michaelmorrow',
#   'adamsthomas',
#   'edwardszachary',
#   'smithkara',
#   'walshspencer',
#   'davidfisher',
#   'vegaantonio'],
#  'Forest/woodland manager': ['carterpatricia',
#   'patrickshaw',
#   'trevoralvarez',
#   'christopherhodges',
#   'laradebra',
#   'nancy33',
#   'kevinvaldez',
#   'maybrandi',
#   'harrisbailey',
#   'theresa02',
#   'johnochoa',
#   'garzacorey',
#   'vargasjoshua',
#   'kennethgreene',
#   'wangvincent',
#   'mitchellronald',
#   'kwilliams',
#   'brownjack',
#   'stacythomas',
#   'wilkersonpatricia',
#   'mark73',
#   'justinmarsh',
#   'ashley92',
#   'suttonjonathan'],
#  'Administrator, education': ['daviddean',
#   'matthewsmith',
#   'gstevens',
#   'adam19',
#   'shari69',
#   'williamaguirre',
#   'opatel',
#   'scottriley',
#   'richardsmichael',
#   'robertsrachel',
#   'martinelizabeth',
#   'katelyn13',
#   'kelly93',
#   'qmueller',
#   'chasebarnes',
#   'wwilliams',
#   'alejandrameyer',
#   'wvasquez',
#   'donald21',
#   'stephaniesnyder',
#   'ronaldatkinson',
#   'james74',
#   'robert25',
#   'pacerachael',
#   'imccarthy',
#   'caitlynmathews',
#   'mark21',
#   'ahaley',
#   'ashley92'],
#  'Nurse, adult': ['roberto27',
#   'rarcher',
#   'alisontodd',
#   'craigallen',
#   'russelljeffrey',
#   'yatesheather',
#   'grahambrian',
#   'michaelwagner',
#   'mario39',
#   'jose78',
#   'matthew61',
#   'fletcherdavid',
#   'stephanie41',
#   'xweber',
#   'brendahill',
#   'amanda55',
#   'rossshelly',
#   'ysmith',
#   'beankatelyn',
#   'xkeith',
#   'jennifer43',
#   'thomasmann',
#   'mariesmith',
#   'ashley92'],
#  'Multimedia programmer': ['vharris',
#   'elizabeth23',
#   'elizabeth97',
#   'heatherriley',
#   'andrea74',
#   'csandoval',
#   'jasminpeterson',
#   'hernandezlaura',
#   'grace88',
#   'rodriguezmatthew',
#   'johnsonemily',
#   'xescobar',
#   'shepherdmichelle',
#   'raydavis',
#   'josephwalker',
#   'irussell',
#   'millskristen',
#   'jonesnancy',
#   'kristinejones',
#   'josephholmes',
#   'nicole01',
#   'candacerusso',
#   'fhughes',
#   'denisewilliams',
#   'timothythompson',
#   'millercrystal',
#   'hunter26',
#   'samuel18',
#   'kimsalinas',
#   'ashley92'],
#  'Civil Service fast streamer': ['williamsdawn',
#   'xgoodman',
#   'xadams',
#   'rzavala',
#   'christopher22',
#   'jenny81',
#   'nicole01',
#   'sjones',
#   'dianejackson',
#   'lambertjimmy',
#   'jonathanbrown',
#   'tamara08',
#   'whiterichard',
#   'berryjohn',
#   'alexandra42',
#   'brandonparks'],
#  'Psychologist, prison and probation services': ['rivasanthony',
#   'jamiegreen',
#   'crystalsmith',
#   'csmith',
#   'kristengreen',
#   'aortega',
#   'davidyoung',
#   'barrnathaniel',
#   'amanda43',
#   'james03',
#   'garrisonamanda',
#   'pamelacollins',
#   'sextonelizabeth',
#   'douglas36',
#   'chaneychristopher',
#   'tamara08',
#   'nicoleprice',
#   'taylor66',
#   'kellymorris',
#   'ybailey',
#   'tramsey',
#   'robert22',
#   'xferrell',
#   'kaylasteele',
#   'amymills'],
#  'Armed forces training and education officer': ['melanierussell',
#   'cwilliams',
#   'wilsonjames',
#   'lbrooks',
#   'kcastro',
#   'morrisshelia',
#   'tracysmith',
#   'snyderross',
#   'sflynn',
#   'dennissherry',
#   'zacharymyers',
#   'johnadams',
#   'jamie16',
#   'princejared',
#   'william24',
#   'bmendoza',
#   'zwebb',
#   'wigginsmary',
#   'xedwards',
#   'garciajenna',
#   'robbinskara',
#   'georgesanchez',
#   'johnramirez',
#   'tamara08',
#   'holtwilliam',
#   'laurennorris',
#   'perezlance',
#   'zimmermanjessica',
#   'nnash',
#   'yatesheather',
#   'smithjonathan'],
#  'Glass blower/designer': ['wendyrojas',
#   'ruth47',
#   'erictrujillo',
#   'lmartinez',
#   'morrisshelia',
#   'leecarol',
#   'sarahtran',
#   'christineperez',
#   'amy84',
#   'robert16',
#   'rickylee',
#   'fitzgeraldcaleb',
#   'joykent',
#   'cassandra89',
#   'graytanya',
#   'wendy88',
#   'gibbslisa',
#   'josephcourtney',
#   'christine21',
#   'tamara08',
#   'robinsonleslie',
#   'ureed',
#   'millerrebecca',
#   'dpeterson',
#   'uguerra',
#   'alexander04'],
#  'Pharmacist, hospital': ['james89',
#   'carolyn64',
#   'megan98',
#   'brenda64',
#   'jerryjackson',
#   'ldurham',
#   'ryoung',
#   'boyleshawn',
#   'bartonlouis',
#   'bcunningham',
#   'john92',
#   'alison86',
#   'coreyryan',
#   'jdavis',
#   'tamara08',
#   'simmonskelly',
#   'cristina76',
#   'robinsoncrystal',
#   'elizabeth95'],
#  'Warehouse manager': ['matthewsmith',
#   'trevinodawn',
#   'whitejessica',
#   'stephanie69',
#   'davidmarquez',
#   'ariasdanielle',
#   'vegaantonio',
#   'xpaul',
#   'wrightkenneth',
#   'barbara76',
#   'pbaird',
#   'joshualloyd',
#   'catherinesnow',
#   'matthew90',
#   'nwest',
#   'brandyprice',
#   'xjenkins',
#   'lsaunders',
#   'vdunn',
#   'roberttravis',
#   'ktaylor',
#   'cindy14',
#   'matthewsuarez',
#   'amber03',
#   'richardsstephen',
#   'kaylanichols'],
#  'Psychologist, counselling': ['kevinhernandez',
#   'selliott',
#   'hardylucas',
#   'gparrish',
#   'vanessa16',
#   'yhiggins',
#   'catherineross',
#   'alex54',
#   'fitzgeraldcaleb',
#   'arnoldtiffany',
#   'iwright',
#   'jessicaward',
#   'iadams',
#   'gsmith',
#   'limadeline',
#   'douglas33',
#   'fisherlaurie',
#   'carpentererin',
#   'deniseknight',
#   'robertmiller',
#   'ashley12',
#   'rodriguezsamuel',
#   'brianamorton',
#   'richardsstephen'],
#  'Pensions consultant': ['rossdoris',
#   'fsmith',
#   'brookehammond',
#   'stephanie69',
#   'foconnor',
#   'ericarobertson',
#   'pbradshaw',
#   'robert81',
#   'kevinvaldez',
#   'reynoldspatrick',
#   'mccoyjonathan',
#   'markmendoza',
#   'carlos09',
#   'robinsongordon',
#   'charlesbuck',
#   'wilsonjennifer',
#   'derrickmason',
#   'briannagarcia',
#   'hoffmansharon',
#   'dunntheresa',
#   'jean88',
#   'ycruz',
#   'richardsstephen'],
#  'Trade mark attorney': ['eileen57',
#   'nicolethornton',
#   'ian79',
#   'natalieferguson',
#   'davidreynolds',
#   'tmiller',
#   'medinagregory',
#   'vincentroberts',
#   'stephanie09',
#   'vincentmoore',
#   'jayclark',
#   'jerryyoung',
#   'natalie14',
#   'jamesfritz',
#   'brittanybender',
#   'dorothy34',
#   'jonathanbrown',
#   'tiffany46',
#   'grimesjanet',
#   'ahamilton',
#   'hernandezvanessa',
#   'kathrynwilliams',
#   'matthew01',
#   'alexandra09',
#   'courtneystein',
#   'laceysmith',
#   'thomasangelica',
#   'santiagocindy',
#   'agregory',
#   'vazquezmitchell',
#   'rjackson',
#   'daniel43',
#   'david31',
#   'lopezkimberly',
#   'laura33',
#   'mjones',
#   'amcdonald',
#   'kgallegos'],
#  'Psychotherapist, child': ['elizabeth19',
#   'raymondwells',
#   'davidreynolds',
#   'jacobrodriguez',
#   'megan77',
#   'qramos',
#   'kempkelly',
#   'leecarol',
#   'kathryn15',
#   'huynhtanya',
#   'williamrussell',
#   'christina91',
#   'jonesamber',
#   'justin68',
#   'katherine59',
#   'alisonkennedy',
#   'james57',
#   'qanderson',
#   'jennifer06',
#   'travisgalloway',
#   'fstanley',
#   'tammyshannon',
#   'kmyers',
#   'perry81',
#   'andrea39',
#   'cassandrataylor'],
#  'Bonds trader': ['martincrystal',
#   'brandy31',
#   'imoss',
#   'morrismichelle',
#   'cdixon',
#   'vjohnson',
#   'mossmichael',
#   'davidreynolds',
#   'sonyagarza',
#   'derek34',
#   'snyderross',
#   'michaelanderson',
#   'christopherrice',
#   'justin94',
#   'stephen61',
#   'sarascott',
#   'michaelcrane',
#   'ydavis',
#   'nicolecameron',
#   'romeromark',
#   'austingonzalez',
#   'andersonbrandy',
#   'hallerik',
#   'lpittman',
#   'jennamejia',
#   'andrea31',
#   'zthompson',
#   'robertmiller',
#   'fordmatthew',
#   'mward',
#   'jonesjoanne',
#   'nashwilliam',
#   'higginsdavid'],
#  'Journalist, broadcasting': ['washingtonangelica',
#   'vasquezcharles',
#   'davidreynolds',
#   'frederickmelissa',
#   'vasquezjoy',
#   'oconnorkatherine',
#   'deckerthomas',
#   'derricksaunders',
#   'vasquezstephen',
#   'pkelly',
#   'kellersteven',
#   'aprilproctor',
#   'bwagner',
#   'ericmiller',
#   'stanleyteresa',
#   'thomassimmons',
#   'kimberlylarsen',
#   'davidbell',
#   'trandolph',
#   'carriesingh',
#   'xthomas',
#   'xherman',
#   'raymondperry',
#   'brennanmargaret',
#   'dawnsanchez',
#   'gabriel30'],
#  'Advice worker': ['wjones',
#   'jesse53',
#   'nwright',
#   'michaelhartman',
#   'brownjulie',
#   'shawnrobinson',
#   'veronicaramirez',
#   'justinsheppard',
#   'jamie06',
#   'nburnett',
#   'wendy57',
#   'jdouglas',
#   'juliegalloway',
#   'briandavis',
#   'caleb69',
#   'xescobar',
#   'damonmercer',
#   'claytonmark',
#   'lsmith',
#   'mbean',
#   'james74',
#   'danielbarton',
#   'elizabeth02',
#   'tanderson',
#   'feliciadominguez',
#   'vanessalewis',
#   'wilsonjonathan',
#   'ronaldroy'],
#  'Geologist, wellsite': ['reidangie',
#   'qking',
#   'ybennett',
#   'dsmith',
#   'joel18',
#   'ddelacruz',
#   'eric89',
#   'ethanmcdaniel',
#   'reesejohn',
#   'jamie54',
#   'stephen61',
#   'nburnett',
#   'patriciamcgee',
#   'gfox',
#   'normataylor',
#   'chelseagonzalez',
#   'roylauren',
#   'cbishop',
#   'crice',
#   'jdavis',
#   'whitneynixon',
#   'harrisonsusan',
#   'amy71',
#   'richard23',
#   'andrewmartin',
#   'christina19',
#   'browncarlos',
#   'lrivers',
#   'wilsonjonathan',
#   'brianamorton',
#   'anthonyphillips'],
#  'Toxicologist': ['joseph17',
#   'richardrhodes',
#   'erika21',
#   'amybrady',
#   'johnsonmelissa',
#   'grace97',
#   'nburnett',
#   'jacquelinechang',
#   'slucero',
#   'courtneymendez',
#   'pamelacollins',
#   'garrettcody',
#   'aprilgarcia',
#   'vgentry',
#   'ktaylor',
#   'williamsonkyle',
#   'sbaker',
#   'mark21',
#   'ztucker',
#   'shawnking',
#   'xfritz'],
#  'Media buyer': ['yvonne67',
#   'poolesara',
#   'timothy68',
#   'dmartinez',
#   'jack57',
#   'amandabenson',
#   'lewisjames',
#   'vrodriguez',
#   'michaelvasquez',
#   'woodjustin',
#   'kmccormick',
#   'jenniferlee',
#   'kenneth98',
#   'murphytommy',
#   'lynnsmith',
#   'wrightkelly',
#   'leejeffrey',
#   'hayneswilliam',
#   'gerald12',
#   'snyderdebra',
#   'vtaylor',
#   'teresaperez',
#   'xadams',
#   'hernandezdenise',
#   'lshields',
#   'timothygay',
#   'kimberly63',
#   'emily07'],
#  'Engineer, civil (consulting)': ['utanner',
#   'colin37',
#   'jamesthomas',
#   'adamserin',
#   'stephanie81',
#   'jenniferanderson',
#   'brownjohn',
#   'jamesfritz',
#   'ryoung',
#   'williamholt',
#   'robertdowns',
#   'aaron53',
#   'delgadoandrew',
#   'villegasaaron',
#   'sarahjames',
#   'jeremiaharmstrong',
#   'kennethjones',
#   'brookslori',
#   'deborahrogers',
#   'sarah50',
#   'sheilamitchell',
#   'cbishop',
#   'cchristensen',
#   'tsanders',
#   'deanna58',
#   'gcontreras',
#   'walkerjulie',
#   'dpeterson',
#   'beanangela',
#   'natalie71',
#   'kimberly63',
#   'paultodd',
#   'vferguson',
#   'hwilliams',
#   'johnnystrickland'],
#  'Corporate treasurer': ['brichardson',
#   'oday',
#   'cwilliams',
#   'lisafoster',
#   'kimberlygrant',
#   'xrodriguez',
#   'grace97',
#   'herringrobert',
#   'christinapena',
#   'nicholas60',
#   'jennifer75',
#   'clynn',
#   'cevans',
#   'johnrogers',
#   'brandigreen',
#   'edwardsaustin',
#   'limadeline',
#   'cwright',
#   'christopher08',
#   'amy71',
#   'jonathonreyes',
#   'elewis',
#   'bradleydavis',
#   'milleramanda',
#   'edwin92',
#   'xjohnson',
#   'donaldking',
#   'kimberly63',
#   'dthompson',
#   'rogerssharon',
#   'xfritz',
#   'adam13'],
#  'Nature conservation officer': ['zimmermanelizabeth',
#   'jeremiah97',
#   'williamsmith',
#   'iholland',
#   'coleolivia',
#   'lindseysimpson',
#   'princejared',
#   'daniel73',
#   'brian89',
#   'egray',
#   'lindsey03',
#   'bcunningham',
#   'buckleyrebecca',
#   'garrettcody',
#   'michellehernandez',
#   'johnrogers',
#   'yford',
#   'spencersmith',
#   'phorton',
#   'mgonzales',
#   'kristen66',
#   'cheryl29',
#   'bwashington',
#   'katherinereeves',
#   'ysmith',
#   'zstrong',
#   'matthew67',
#   'awebster'],
#  'Neurosurgeon': ['wilcoxnicole',
#   'lisafoster',
#   'buchananjohn',
#   'sextonsheila',
#   'preston39',
#   'jeremyjones',
#   'kristine37',
#   'camachodouglas',
#   'lindsey03',
#   'michelle00',
#   'iharris',
#   'wwilliams',
#   'heathertaylor',
#   'andreagonzalez',
#   'cheryl12',
#   'thoward',
#   'shanewalsh',
#   'wilkersonpatricia',
#   'jessicaduncan',
#   'carrbrian',
#   'kblack',
#   'haynestamara'],
#  'Special effects artist': ['davidwilliams',
#   'derrick72',
#   'mary45',
#   'christopher05',
#   'joneskimberly',
#   'frederickrodgers',
#   'smithelizabeth',
#   'george48',
#   'sandrahouston',
#   'frenchshane',
#   'ihill',
#   'donna73',
#   'iwright',
#   'lyonstracy',
#   'woodjustin',
#   'amanda97',
#   'lindsey03',
#   'markolson',
#   'porterlatoya',
#   'michellewilson',
#   'brian42',
#   'steven69',
#   'ohayden',
#   'timothybrown',
#   'kimberlybrooks',
#   'ysmith',
#   'shahlori'],
#  'Professor Emeritus': ['jamesmckenzie',
#   'hmiddleton',
#   'deborahalvarez',
#   'kmelton',
#   'lucerojaclyn',
#   'munozadam',
#   'cruzwilliam',
#   'villarrealcynthia',
#   'lucas04',
#   'danieldavis',
#   'candacebarnes',
#   'jarviscourtney',
#   'rickylee',
#   'trujilloashley',
#   'hendersonkyle',
#   'lindsey03',
#   'sheltonjoseph',
#   'emurphy',
#   'smorales',
#   'sweber',
#   'derrickli',
#   'david94',
#   'zachary99',
#   'zgray',
#   'henrybutler',
#   'ebates',
#   'buchanancarrie',
#   'sschmidt',
#   'shawkins'],
#  'Rural practice surveyor': ['stokescheryl',
#   'kenneth60',
#   'ubell',
#   'nfleming',
#   'delgadotimothy',
#   'tsmith',
#   'thomasstein',
#   'jennifer74',
#   'haleyjessica',
#   'rstanley',
#   'laurenharris',
#   'michael63',
#   'brookeburke',
#   'amber13',
#   'laurie16',
#   'william24',
#   'mitchellkyle',
#   'katherinewalters',
#   'lindsey03',
#   'randy45',
#   'michaelguzman',
#   'davidturner',
#   'brookslori',
#   'hschneider',
#   'pittsbrandy',
#   'briancochran',
#   'alexander31',
#   'sherrianderson',
#   'thoward',
#   'michaelrandall',
#   'adam63',
#   'april65',
#   'zbrown',
#   'nnash'],
#  'Education administrator': ['natasha36',
#   'jpoole',
#   'jacquelinehuber',
#   'mark01',
#   'andrew67',
#   'ypowell',
#   'nathanklein',
#   'smithelizabeth',
#   'carlallen',
#   'garybrown',
#   'rickylee',
#   'pricelisa',
#   'smithmichael',
#   'patrick77',
#   'uhamilton',
#   'richardgreene',
#   'alvinwilson',
#   'andrewwoods',
#   'collinsjessica',
#   'courtneymendez',
#   'davidsmith',
#   'villegasaaron',
#   'alexandra09',
#   'tfoster',
#   'jenniferwagner',
#   'sallen',
#   'mwilkerson',
#   'benjamin86',
#   'shannon49',
#   'eileen79',
#   'ureed',
#   'tkey',
#   'xadams',
#   'maldonadosarah',
#   'caseyvelasquez',
#   'gravesjim',
#   'luis44'],
#  'Arboriculturist': ['christopherjones',
#   'laurenbranch',
#   'qwoodard',
#   'evelynhill',
#   'shernandez',
#   'carlallen',
#   'rhood',
#   'davidingram',
#   'grace97',
# ...
#   'robert71',
#   'kimberly18',
#   'vwatts',
#   'kingdustin',
#   'shannonerika',
#   'wallaceangel',
#   'richardgreene',
#   'aliciaturner',
#   'lawrenceevans',
#   'kristinaray',
#   'uchen',
#   'jessicali',
#   'brownalyssa',
#   'vazquezmitchell',
#   'fsexton',
#   'brentgutierrez',
#   'jsmith',
#   'tyler88'],
#  'Freight forwarder': ['brittany19',
#   'ruth47',
#   'mejiathomas',
#   'ycook',
#   'davidsolomon',
#   'gregorysmith',
#   'torreschristian',
#   'heather20',
#   'dgarcia',
#   'markwatts',
#   'donaldhill',
#   'kathleenrice',
#   'rlong',
#   'mirandamckenzie',
#   'christie80',
#   'karen49',
#   'ztaylor',
#   'derrickmason',
#   'wintersbrenda',
#   'dchan',
#   'zgross',
#   'nataliejohnson'],
#  'Psychiatrist': ['hernandezjulie',
#   'katherine75',
#   'kmccormick',
#   'ramseyjoanna',
#   'ybailey',
#   'hawkinsandrea',
#   'ganderson',
#   'framirez',
#   'fosterrobert',
#   'anthony75',
#   'karen62',
#   'ian64',
#   'valeriemendoza',
#   'tiffanyjohnson',
#   'alexandra55',
#   'michael39',
#   'danielle13',
#   'torreschristian'],
#  'Economist': ['alyssa94',
#   'audreyhuerta',
#   'smithmelissa',
#   'gabriel79',
#   'cmartinez',
#   'matthewortiz',
#   'michelledecker',
#   'smithkara',
#   'aaronobrien',
#   'russelljeffrey',
#   'hodgetracy',
#   'rachelbrown',
#   'jamie49',
#   'jamesshawn',
#   'amandamartinez',
#   'martinwesley',
#   'ashley59',
#   'tharris',
#   'jared28',
#   'mariafowler',
#   'johnheath',
#   'cbishop',
#   'daniellemcguire',
#   'theresacooper',
#   'jennifer45',
#   'jennifertate',
#   'ehernandez',
#   'monique00',
#   'morrisontimothy',
#   'lopezkimberly'],
#  'Quarry manager': ['geraldmcdonald',
#   'john93',
#   'stewartjoel',
#   'jordan80',
#   'victoriazamora',
#   'michaelsoto',
#   'kelseygaines',
#   'basskevin',
#   'harry08',
#   'jeremy27',
#   'patrick34',
#   'khanbrandon',
#   'fbarr',
#   'juliedavis',
#   'kellyatkinson',
#   'baxtermichele',
#   'kevin60',
#   'sweber',
#   'james09',
#   'zpowers',
#   'zachary99',
#   'stewartjason',
#   'daniellerodgers',
#   'mendozadana',
#   'kathrynlewis',
#   'haleyfowler',
#   'rroman',
#   'ygriffith',
#   'ronald90',
#   'richard00',
#   'jonesjason',
#   'rmiddleton',
#   'adam13'],
#  'Therapist, nutritional': ['paularnold',
#   'fpham',
#   'john84',
#   'brentsmith',
#   'frederickrodgers',
#   'andreawilliams',
#   'griffinkenneth',
#   'samuelpatterson',
#   'charles66',
#   'jbarnes',
#   'xedwards',
#   'johnleonard',
#   'jenniferburgess',
#   'donna17',
#   'garciathomas',
#   'douglashendricks',
#   'lisahawkins',
#   'garytorres',
#   'millercrystal'],
#  'Production assistant, radio': ['haileyfernandez',
#   'sanchezsheila',
#   'patriciaprice',
#   'fburton',
#   'virginiaduncan',
#   'shelbykelley',
#   'tsmith',
#   'michaeljohnson',
#   'patrick36',
#   'swilliams',
#   'ramirezkeith',
#   'wmorris',
#   'fredhudson',
#   'jacobsonbarbara',
#   'nancy47',
#   'dorothy34',
#   'tlamb',
#   'leonardberg',
#   'gfritz',
#   'ejennings',
#   'jennifer75',
#   'scottmiller',
#   'wuerika',
#   'penaglen',
#   'istanton',
#   'wpalmer',
#   'milleramanda',
#   'edwin92',
#   'bauerpatricia',
#   'hickssonya',
#   'wgray'],
#  'Web designer': ['melanierussell',
#   'smithmelissa',
#   'ianlandry',
#   'gdavis',
#   'swood',
#   'lallen',
#   'craigmckay',
#   'fredhudson',
#   'desireejohnson',
#   'danaberg',
#   'cbryant',
#   'vewing',
#   'kenneth98',
#   'kevintaylor',
#   'traceyleblanc',
#   'lisamorales',
#   'mbarnes',
#   'weberlisa',
#   'cheryltownsend',
#   'cmalone',
#   'melissamorse',
#   'vcarlson',
#   'millercrystal',
#   'kevinpeters'],
#  'Ambulance person': ['tyler76',
#   'douglas91',
#   'nicolewhite',
#   'dunntheresa',
#   'zachary47',
#   'robert71',
#   'gdavis',
#   'amorris',
#   'ericarobertson',
#   'kleinkristina',
#   'nescobar',
#   'smcknight',
#   'robertshaley',
#   'buckleyrebecca',
#   'hcook',
#   'fcline',
#   'mejianicholas',
#   'crosbystacy',
#   'katie27',
#   'ylowe',
#   'jerry77',
#   'mschmidt',
#   'teresaperez',
#   'kimberlybrooks',
#   'whitney83',
#   'andreamurphy',
#   'thomasmann',
#   'bellsandra',
#   'cchen',
#   'gabriel30'],
#  'Chartered legal executive (England and Wales)': ['roachscott',
#   'michealmarsh',
#   'richard31',
#   'jon91',
#   'frankspencer',
#   'nancytaylor',
#   'briana29',
#   'hannahcochran',
#   'thomasstephen',
#   'hornsherry',
#   'fbrown',
#   'sarahmiller',
#   'alison86',
#   'lbeard',
#   'kathrynjones',
#   'samantha31',
#   'tmitchell',
#   'lambertjimmy',
#   'smithmarie',
#   'shawnking'],
#  'Field seismologist': ['bgonzalez',
#   'vtodd',
#   'mccoyjonathan',
#   'judithramirez',
#   'connerwilliam',
#   'bjohnson',
#   'edwin88',
#   'rebecca50',
#   'carolineedwards',
#   'ebrooks',
#   'xreeves',
#   'nstrickland',
#   'crichard',
#   'cassandrataylor',
#   'nancygriffin',
#   'destinyjones',
#   'thomasstephen',
#   'frankcynthia'],
#  'Scientist, clinical (histocompatibility and immunogenetics)': ['cheryl23',
#   'hollandryan',
#   'ypowell',
#   'millerpaul',
#   'howardvalerie',
#   'victoria68',
#   'riveraalex',
#   'garyscott',
#   'chadandrews',
#   'johnsonmatthew',
#   'youngheidi',
#   'omiller',
#   'melissa40',
#   'gcarey',
#   'katie27',
#   'jamessmith',
#   'katie07',
#   'qmay',
#   'amy71',
#   'elizabethhamilton',
#   'zstrong',
#   'christophermiller'],
#  'Prison officer': ['ustuart',
#   'lmartin',
#   'patriciaprice',
#   'larry11',
#   'ianlandry',
#   'caseydominic',
#   'kbarber',
#   'swilliams',
#   'jeanne01',
#   'rleblanc',
#   'hodgetracy',
#   'munozray',
#   'josephcarroll',
#   'hansendavid',
#   'craigewing',
#   'mooresarah',
#   'kimberlylarsen',
#   'nataliesalazar',
#   'michaelphillips',
#   'brad46',
#   'natalie52',
#   'htaylor',
#   'zstewart',
#   'meghan34',
#   'ritajohnson',
#   'sschmidt',
#   'imcguire',
#   'daviddeleon'],
#  'Engineer, electrical': ['robertsontodd',
#   'mnguyen',
#   'brittney74',
#   'joseph56',
#   'petergriffin',
#   'leonardberg',
#   'shirley71',
#   'traciewells',
#   'cdavid',
#   'kellymichael',
#   'lbeard',
#   'johnrogers',
#   'davisgeorge',
#   'xyoung',
#   'hallcarolyn',
#   'oliverstephen',
#   'whitneyschwartz',
#   'michellemcfarland',
#   'chavezsheila',
#   'brownjacob',
#   'zgross',
#   'benjamin54'],
#  'Forensic scientist': ['ricky88',
#   'amanda41',
#   'lisa09',
#   'urangel',
#   'djimenez',
#   'aallison',
#   'gjacobson',
#   'delgadojason',
#   'reynoldspatrick',
#   'ortegalisa',
#   'hornsherry',
#   'chasebarnes',
#   'ejackson',
#   'zmorrison',
#   'katiegarrison',
#   'kathy01',
#   'wmoses',
#   'ucruz',
#   'mdavis',
#   'ekelly',
#   'simmonstanya',
#   'william68',
#   'courtneymorales',
#   'nstrickland',
#   'tpennington',
#   'jodiriley',
#   'watsonrebecca'],
#  'English as a second language teacher': ['fowleradam',
#   'jamesdunn',
#   'edwinbailey',
#   'harrischristopher',
#   'jillibarra',
#   'jessica19',
#   'andrew26',
#   'combsselena',
#   'wayne99',
#   'susannelson',
#   'deantimothy',
#   'holderelizabeth',
#   'michelle68',
#   'sharonhicks',
#   'velezaudrey',
#   'robinjackson',
#   'ktaylor',
#   'hawkinswilliam',
#   'thompsonthomas',
#   'nicoleberg',
#   'sandramiller',
#   'danielle79'],
#  'Psychologist, occupational': ['cparker',
#   'kathryn38',
#   'sandra18',
#   'connerthomas',
#   'buchananjohn',
#   'stephenjones',
#   'natalieross',
#   'carlallen',
#   'craigallen',
#   'sarascott',
#   'roymichael',
#   'joshua38',
#   'christopher06',
#   'linda03',
#   'ebrown',
#   'xmedina',
#   'michellehernandez',
#   'woodschristopher',
#   'mcdanielrobert',
#   'egreen'],
#  'Arts administrator': ['bfranco',
#   'mejianicholas',
#   'matthewdavis',
#   'kaitlyn65',
#   'ucarlson',
#   'ricedestiny',
#   'hicksjeff',
#   'stephanie16',
#   'jacobsonbarbara',
#   'simmonstanya',
#   'karenhall',
#   'garytorres',
#   'lisa77',
#   'robert13',
#   'brittany34',
#   'thomasreginald',
#   'brandonparks'],
#  'Ergonomist': ['holmescarolyn',
#   'zmcpherson',
#   'justindouglas',
#   'goodmatthew',
#   'nicole93',
#   'sarahkey',
#   'mejiathomas',
#   'jeffreydavila',
#   'makaylaking',
#   'akennedy',
#   'kaitlynshelton',
#   'elliskenneth',
#   'heather20',
#   'zimmermanchad',
#   'jenniferburgess',
#   'laurie37',
#   'josephcole',
#   'thomasreginald',
#   'elizabethhamilton',
#   'heather97',
#   'shannon43',
#   'cheryltownsend'],
#  'Passenger transport manager': ['buchananjohn',
#   'william22',
#   'billy00',
#   'timothy37',
#   'annemitchell',
#   'xrodriguez',
#   'lwilson',
#   'danielle53',
#   'ericacarpenter',
#   'vkeller',
#   'sanchezlisa',
#   'carol95',
#   'kathleenbarnett',
#   'cevans',
#   'yvonnebailey',
#   'danielle13',
#   'glen28',
#   'ricedestiny',
#   'bethjohnson',
#   'lopezkimberly',
#   'ehicks',
#   'kaitlyn07',
#   'arnoldchristopher',
#   'smithjonathan',
#   'davidsonsamuel'],
#  'Psychologist, forensic': ['timothyknight',
#   'ashley45',
#   'wking',
#   'victoriazamora',
#   'kristyross',
#   'mmills',
#   'jacobsbrittany',
#   'kristengreen',
#   'davidingram',
#   'lshepherd',
#   'jamie16',
#   'morganthomas',
#   'maybrandi',
#   'michael39',
#   'youngjames',
#   'austin18',
#   'timothycook',
#   'lbeard',
#   'yvonnebailey',
#   'ztucker',
#   'jroth',
#   'kaylasteele'],
#  'Sales promotion account executive': ['brownbrandon',
#   'mary45',
#   'morgan82',
#   'velasquezrodney',
#   'carlos61',
#   'lanebenjamin',
#   'keith43',
#   'riveraalex',
#   'cherylsmith',
#   'mwilliams',
#   'anthony22',
#   'michaelmitchell',
#   'danaberg',
#   'wcunningham',
#   'johnheath',
#   'lisamorales',
#   'lopeztanya',
#   'whiterichard',
#   'ygriffith',
#   'gthomas',
#   'nathanhayden',
#   'higginsmichael',
#   'zstewart',
#   'jennifer43',
#   'crystalperez',
#   'michael66'],
#  'Make': ['vflores',
#   'cassandra59',
#   'jgonzalez',
#   'ytownsend',
#   'lfriedman',
#   'richardsmichael',
#   'megan73',
#   'robertsbradley',
#   'pauldrake',
#   'englishlisa',
#   'ehoffman',
#   'hroberts',
#   'christopher03',
#   'murphytommy',
#   'rachelkelley',
#   'ortegaaudrey',
#   'nsmith',
#   'kristiarmstrong',
#   'charlesbuck',
#   'victoria57',
#   'zfuller',
#   'brownlaura',
#   'ruth76',
#   'crystal55',
#   'harrellryan',
#   'victoriajones',
#   'deckerthomas'],
#  'Science writer': ['markchavez',
#   'nancymullins',
#   'carol95',
#   'uboone',
#   'jacksonrobert',
#   'shanewalsh',
#   'annkemp',
#   'michaelsmith',
#   'gibbslisa',
#   'millskristen',
#   'ashleyhale',
#   'urhodes',
#   'thompsonthomas',
#   'tmitchell',
#   'nicole01',
#   'rachel87',
#   'steven77',
#   'kayla66'],
#  'Administrator, Civil Service': ['stevensmicheal',
#   'lee99',
#   'griffinjuan',
#   'kburnett',
#   'allisonbrian',
#   'joseph16',
#   'shirleybrewer',
#   'martha42',
#   'washingtonanne',
#   'vtodd',
#   'iwatkins',
#   'hroberts',
#   'gford',
#   'andreathornton',
#   'lopezlisa',
#   'hrojas',
#   'owheeler',
#   'ghoward',
#   'zfuller',
#   'carlos99'],
#  'Industrial/product designer': ['kmelton',
#   'kvalentine',
#   'joneskimberly',
#   'sandra23',
#   'mistyray',
#   'iwright',
#   'brandon01',
#   'stevengilbert',
#   'stewartdaniel',
#   'christopher73',
#   'katie07',
#   'markchang',
#   'hallcarolyn',
#   'kellymorris',
#   'sherrianderson',
#   'annagreen',
#   'michael45',
#   'ashleystone',
#   'maldonadosarah'],
#  'Community pharmacist': ['elizabeth97',
#   'mejiathomas',
#   'carlsonsharon',
#   'lucasyoung',
#   'rleblanc',
#   'candice75',
#   'jjensen',
#   'ygomez',
#   'porternicole',
#   'blacktyler',
#   'xhaas',
#   'cantudeborah',
#   'emilycruz',
#   'pclarke',
#   'hansonsean',
#   'alison86',
#   'johnmoore',
#   'spencersmith',
#   'vtaylor',
#   'traci94',
#   'michaelrandall',
#   'jfrazier',
#   'amyrodriguez',
#   'fsingh',
#   'william37',
#   'xholland'],
#  'Dramatherapist': ['ugonzalez',
#   'edwardsharp',
#   'nbush',
#   'sarahkey',
#   'pkane',
#   'ochoacharles',
#   'vrodriguez',
#   'kelsey61',
#   'gpatterson',
#   'melanienguyen',
#   'brandonsmith',
#   'becky83',
#   'karenhorton',
#   'chelseagonzalez',
#   'iferrell',
#   'scottmiller',
#   'leejessica',
#   'hoodcheryl',
#   'zbrown',
#   'triciaknapp'],
#  'Pharmacist, community': ['amorrison',
#   'crosbystacy',
#   'paulpaul',
#   'nicole07',
#   'pricejames',
#   'tina65',
#   'brendasilva',
#   'davidmejia',
#   'patriciamcgee',
#   'smithkara',
#   'mathew71',
#   'bbrown',
#   'mark40'],
#  'Engineer, civil (contracting)': ['millerchristina',
#   'ubell',
#   'wendyrojas',
#   'brookehammond',
#   'leblancrachel',
#   'mark71',
#   'joanna34',
#   'christina88',
#   'tranjohn',
#   'jeffreysmith',
#   'yfloyd',
#   'ellisdennis',
#   'arich',
#   'juliasmith',
#   'brad80',
#   'ashleyriggs',
#   'lee46',
#   'nicoleprice',
#   'tsanders',
#   'gwilliams',
#   'wcruz',
#   'christopherrivera',
#   'bmartin',
#   'patrick86'],
#  'Trade union research officer': ['wendyrojas',
#   'gregory67',
#   'savannaharmstrong',
#   'mhurley',
#   'xmitchell',
#   'jamesmorgan',
#   'estout',
#   'adam04',
#   'michaelfernandez',
#   'gpearson',
#   'isaac18',
#   'jeffreymcclain',
#   'jeanneparker',
#   'robert37',
#   'kmendez',
#   'hubbardmichelle',
#   'elizabeth95',
#   'esalazar',
#   'lance60',
#   'carlos99'],
#  'Fish farm manager': ['evelynhill',
#   'thomas61',
#   'ssims',
#   'harringtonsean',
#   'samuelwilliams',
#   'deanna09',
#   'harry44',
#   'reyeswendy',
#   'manuelalexander',
#   'kathryngriffin',
#   'stephen82',
#   'jonathanbrown',
#   'mgarcia',
#   'blakemiranda',
#   'zpowers',
#   'phyllis72',
#   'ruth76',
#   'tracythomas',
#   'oroberson',
#   'jknight',
#   'alexandra55'],
#  'Research scientist (physical sciences)': ['vflores',
#   'anthonybarry',
#   'fpham',
#   'taylormichelle',
#   'troth',
#   'jonesmatthew',
#   'vmoore',
#   'mark71',
#   'pmclaughlin',
#   'elizabethtaylor',
#   'dennissherry',
#   'nancy94',
#   'mitchellkyle',
#   'kelsey79',
#   'michael37',
#   'fhall',
#   'stevenmeyer',
#   'parkerchristie',
#   'lawsonkayla',
#   'ellisonjohn',
#   'herreranatasha',
#   'theresacooper',
#   'fsexton',
#   'elewis',
#   'hernandezdenise',
#   'hoffmansharon',
#   'johnjackson',
#   'annenguyen'],
#  'Solicitor': ['dnavarro',
#   'leejodi',
#   'krodriguez',
#   'longtimothy',
#   'joanna34',
#   'lesliesmith',
#   'rdominguez',
#   'mcohen',
#   'andreawilliams',
#   'aaronanderson',
#   'pware',
#   'clintonjones',
#   'brett59',
#   'robin46',
#   'fcooper',
#   'gzimmerman',
#   'qhernandez',
#   'whitneyanderson',
#   'romerokristen',
#   'vwilson',
#   'susanclay',
#   'joshuaporter',
#   'wmckenzie',
#   'zbrown'],
#  'Actor': ['gregory08',
#   'vjohnson',
#   'donald45',
#   'nataliemoore',
#   'andrew22',
#   'sandra56',
#   'youngkyle',
#   'mburns',
#   'crobinson',
#   'donna67',
#   'eterry',
#   'ujenkins',
#   'fosterruth',
#   'nicholas72',
#   'xflores',
#   'thomaschristopher',
#   'mperkins',
#   'john33',
#   'joseph91',
#   'stephanie87',
#   'dthompson',
#   'sarah73',
#   'martinezstacy',
#   'williamle',
#   'william37'],
#  'Music tutor': ['millertracy',
#   'gilbertsteven',
#   'patrickshaw',
#   'morrisshelia',
#   'susansantos',
#   'ortegatyler',
#   'erica32',
#   'patrick36',
#   'andrew26',
#   'victoriajohnson',
#   'fergusonjerry',
#   'mark85',
#   'hollyedwards',
#   'ian25',
#   'gfritz',
#   'kristy39',
#   'patrick98',
#   'ashleymarshall',
#   'gonzalezhelen',
#   'gthomas',
#   'fsharp',
#   'christopherlong',
#   'nicole07',
#   'mperkins',
#   'ggreen',
#   'htaylor',
#   'awebster'],
#  'Engineer, production': ['eileen57',
#   'wjones',
#   'qking',
#   'longtimothy',
#   'sonyagarza',
#   'adamkelly',
#   'lopezangela',
#   'oliveraaron',
#   'jessicalang',
#   'martinwesley',
#   'hornsherry',
#   'zwinters',
#   'mwillis',
#   'hweber',
#   'qolson',
#   'tamararodriguez',
#   'michael02',
#   'edward26',
#   'teresaperez',
#   'kmendez',
#   'ztaylor'],
#  'Runner, broadcasting/film/video': ['mbarnes',
#   'lewisgregory',
#   'mark36',
#   'vdelgado',
#   'frenchshane',
#   'danielle52',
#   'adamserin',
#   'zimmermanchad',
#   'xmaldonado',
#   'scottreyes',
#   'cindy77',
#   'kaylaclark',
#   'vincentroberts',
#   'bryce17',
#   'richard70',
#   'jodiklein'],
#  'Medical laboratory scientific officer': ['jon04',
#   'carlarichardson',
#   'daltonmelissa',
#   'jeremy66',
#   'william08',
#   'destinyfisher',
#   'robert21',
#   'claireschultz',
#   'davidyoung',
#   'jamescrystal',
#   'averymaria',
#   'courtneystein',
#   'shaunharris',
#   'kimberly15',
#   'erika95',
#   'pjohnson',
#   'byrdsally',
#   'perezconnor',
#   'jonescheryl',
#   'adam63',
#   'alexander04'],
#  'Manufacturing engineer': ['hodgesmark',
#   'grahambrian',
#   'kenneth98',
#   'mathew49',
#   'angelawalker',
#   'walkerjulie',
#   'kcastro',
#   'edavis',
#   'coryjackson',
#   'faulknerjoel',
#   'gfreeman',
#   'courtney28',
#   'markchang',
#   'kellerjason',
#   'kaisermelissa',
#   'darlene15',
#   'ian25',
#   'alexander31'],
#  'Therapist, occupational': ['georgebrooks',
#   'shirley03',
#   'kurt02',
#   'kleinkristina',
#   'khicks',
#   'martha42',
#   'qbarnes',
#   'villegasaaron',
#   'johnleonard',
#   'hcampbell',
#   'sherrianderson',
#   'stephen01',
#   'cmalone',
#   'snyderandrew',
#   'floydtimothy',
#   'rfrye',
#   'mward',
#   'kellyjimenez',
#   'thomasmann'],
#  'Ranger/warden': ['gmoore',
#   'hollandryan',
#   'karenrhodes',
#   'clayton45',
#   'brownjulie',
#   'howelldwayne',
#   'gregory84',
#   'jerryjackson',
#   'dcruz',
#   'lawsonkayla',
#   'nmiller',
#   'michelle47',
#   'destiny06',
#   'charlesrice',
#   'rrangel',
#   'scooper',
#   'meganbrewer',
#   'kimkara',
#   'scotttyrone',
#   'qjones']}

# %% [markdown]
# 2.2 Сохраните результаты в файл `job_people.pickle` и в файл `job_people.json` с использованием форматов pickle и JSON соответственно. Сравните объемы получившихся файлов. При сохранении в JSON укажите аргумент `indent`.

# %%
with open('job_people.pickle', 'wb') as f:
    pickle.dump(diction, f)
    
with open("job_people.json", "w") as f:
    json.dump(diction, f, indent=3)
    
    
os.path.getsize("job_people.pickle"), os.path.getsize("job_people.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a369c9558c65> in <module>
#       1 with open('job_people.pickle', 'wb') as f:
# ----> 2     pickle.dump(diction, f)
#       3
#       4 with open("job_people.json", "w") as f:
#       5     json.dump(diction, f, indent=3)
#
# NameError: name 'diction' is not defined

# %%
import os.path
print(os.path.getsize('job_people.pickle'))
print(os.path.getsize('job_people.json'))
# Out:
# 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-af98dbd3b206> in <module>
#       1 import os.path
#       2 print(os.path.getsize('job_people.pickle'))
# ----> 3 print(os.path.getsize('job_people.json'))
#
# /usr/lib/python3.9/genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# FileNotFoundError: [Errno 2] No such file or directory: 'job_people.json'

# %% [markdown]
# 2.3 Считайте файл `job_people.pickle` и продемонстрируйте, что данные считались корректно.

# %%
with open("job_people.json", "r") as read_file:
    data1 = json.load(read_file)
    
with open("job_people.pickle", "rb") as read_file:
    data2 = pickle.load(read_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-7b26b4bd6cfa> in <module>
# ----> 1 with open("job_people.json", "r") as read_file:
#       2     data1 = json.load(read_file)
#       3
#       4 with open("job_people.pickle", "rb") as read_file:
#       5     data2 = pickle.load(read_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'job_people.json'

# %%
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6e25229a93f2> in <module>
# ----> 1 data1
#
# NameError: name 'data1' is not defined

# %% [markdown]
# ### XML

# %% [markdown]
# 3.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`

# %%
from bs4 import BeautifulSoup
with open('steps_sample.xml', 'r') as f:
  reader = BeautifulSoup(f, 'xml')

# %%
import json

# %%
ides = []
steps = []
for recipe in reader.recipes.find_all('recipe'):
  ides += [id.next for id in recipe.find_all('id')]
  steps.append([step.next for step in recipe.steps.find_all('step')])
dict_id_steps = {i:j for i,j in zip(ides, steps)}
with open('steps_sample.json', 'w') as f:
  json.dump(dict_id_steps, f, indent = 4)

# %% [markdown]
# 3.2 По данным файла `steps_sample.xml` сформируйте словарь следующего вида: `кол-во_шагов_в_рецепте: [список_id_рецептов]`

# %%
steps_len = []
dict_nsteps_id = {}
for recipe in reader.recipes.find_all('recipe'):
  num_steps = len([step.next for step in recipe.steps.find_all('step')])
  if num_steps not in dict_nsteps_id:
    dict_nsteps_id[num_steps] = [id.next for id in recipe.find_all('id')]
  else:
    dict_nsteps_id[num_steps] += [id.next for id in recipe.find_all('id')]
for i in dict_nsteps_id:
  print(i, ':', dict_nsteps_id[i])

# %% [markdown]
# 3.3 Получите список рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов.

# %%
id_recipe = []
for recipe in reader.find_all('recipe'):
  for steps in recipe.find_all('steps'):
    if 'has_hours' in steps.step.attrs or 'has_minutes' in steps.step.attrs:
      id_recipe.append(recipe.find('id').next)
print(id_recipe)

# %% [markdown]
# 3.4 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений.

# %%
recipes = pd.read_csv("recipes_sample.csv", sep=',', parse_dates=['submitted'])
recipes = recipes.set_index("id")
recipes

# %% [markdown]
# 3.5 Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5d01702bba1a> in <module>
# ----> 1 print(recipes['n_steps'].isnull().sum())
#       2 recipes['n_steps'] = recipes['n_steps'].astype('int')
#       3 recipes.to_csv('recipes_sample_with_filled_nsteps.csv')
#
# NameError: name 'recipes' is not defined
